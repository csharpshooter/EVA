# %% [markdown]
# # Import Libraries

# %%
import datetime
print("Model execution started at:" + datetime.datetime.today().ctime())
# Out:
# Model execution started at:Sun Mar  8 23:58:15 2020

# %%
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
import src.preprocessing.preprocessing as preprocessing
import src.utils.utils as utils
import src.models.train_model as train
import src.visualization.plotdata as plotdata
# %config IPCompleter.greedy=True

# %%
def printgpuinfo():
    gpu_info = !nvidia-smi
    gpu_info = '\n'.join(gpu_info)
    if gpu_info.find('failed') >= 0:
      print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
      print('and then re-execute this cell.')
    else:
      print(gpu_info)

# %%
def showsysteminfo():
    from psutil import virtual_memory
    ram_gb = virtual_memory().total / 1e9
    print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

    if ram_gb < 20:
      print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
      print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
      print('re-execute this cell.')
    else:
      print('You are using a high-RAM runtime!')

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
preproc = preprocessing.Preprocessing()
train_transforms = preproc.gettraintransforms()
test_transforms = preproc.gettesttransforms()

# %%
ds = dst.Dataset()
train_dataset = ds.gettraindataset(train_transforms)
test_dataset = ds.gettestdataset(test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 128
dataloader = dl.Cifar10Dataloader(traindataset=train_dataset, testdataset=test_dataset,batch_size=batch_size)
train_loader = dataloader.gettraindataloader()
test_loader = dataloader.gettestdataloader()
# Out:
# CUDA Available? True
# 128

# %%
# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

dataiterator = iter(train_loader)
plotdata.PlotData.showImagesfromdataset(dataiterator,classes=classes)

# %%
cnn_model, device = utils.Utils.createmodelresnet18()
train_model = train.TrainModel()
train_model.showmodelsummary(cnn_model)
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
optimizer = utils.Utils.createoptimizer(cnn_model, lr=0.015, momentum=0.9, weight_decay=0) #0.01
eps=1e-08
current_lr = 0
new_lr = 0
increasing = True


reducingSchedulerFactor = 0.1
increasingSchedulerFactor = 0.001/0.1

reducingScheduler = utils.Utils.createscheduler(optimizer, mode='max', factor=reducingSchedulerFactor, 
                                                patience=2,verbose=True,eps=eps)
increasingScheduler = utils.Utils.createscheduler(optimizer, mode='max', factor=increasingSchedulerFactor,
                                                  patience=2,verbose=True,eps=eps)

# %%
lr_data = []
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
epochs = 51
for epoch in range(1, epochs):
    print("EPOCH:", epoch)
    train_model.train(cnn_model, device, train_loader, optimizer, 1)
    t_acc_epoch = train_model.test(cnn_model, device, test_loader, class_correct=class_correct,
                                   class_total=class_total, epoch=epoch)
    
    for param_groups in optimizer.param_groups:
        current_lr = param_groups['lr'];
    
    if(1e-05 <= current_lr <= reducingSchedulerFactor):
        increasing = False
        decreasing = True
        reducingScheduler.step(t_acc_epoch)
        print("reducing")
    else:
        print("increasing")
        increasing = True
        decreasing = False
        increasingScheduler.step(t_acc_epoch)

        
    for param_groups in optimizer.param_groups:
        print("Learning rate =", param_groups['lr'], " for epoch: ", epoch + 1)  # print LR for different epochs
        lr_data.append(param_groups['lr'])
        new_lr = param_groups['lr'];
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 1
# /home/abhijit/.virtualenvs/dl4cv/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=1.2906004190444946 Batch_id=390 Accuracy=43.19: 100%|██████████| 391/391 [00:50<00:00,  7.76it/s]
# Test set: Average loss: 0.0094, Accuracy: 5765/10000 (57.65%)
#
# Validation accuracy increased (0.000000 --> 57.650000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  2
# EPOCH: 2
# Loss=1.045757532119751 Batch_id=390 Accuracy=60.37: 100%|██████████| 391/391 [01:00<00:00,  6.44it/s]
# Test set: Average loss: 0.0082, Accuracy: 6497/10000 (64.97%)
#
# Validation accuracy increased (57.650000 --> 64.970000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  3
# EPOCH: 3
# Loss=0.8112024068832397 Batch_id=390 Accuracy=68.19: 100%|██████████| 391/391 [01:02<00:00,  6.21it/s]
# Test set: Average loss: 0.0074, Accuracy: 6842/10000 (68.42%)
#
# Validation accuracy increased (64.970000 --> 68.420000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  4
# EPOCH: 4
# Loss=0.9234999418258667 Batch_id=390 Accuracy=72.82: 100%|██████████| 391/391 [01:05<00:00,  6.00it/s]
# Test set: Average loss: 0.0061, Accuracy: 7411/10000 (74.11%)
#
# Validation accuracy increased (68.420000 --> 74.110000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  5
# EPOCH: 5
# Loss=0.4669322371482849 Batch_id=390 Accuracy=75.95: 100%|██████████| 391/391 [01:06<00:00,  5.84it/s]
# Test set: Average loss: 0.0049, Accuracy: 7834/10000 (78.34%)
#
# Validation accuracy increased (74.110000 --> 78.340000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  6
# EPOCH: 6
# Loss=0.665722668170929 Batch_id=390 Accuracy=77.95: 100%|██████████| 391/391 [01:04<00:00,  6.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 7755/10000 (77.55%)
#
# reducing
# Learning rate = 0.015  for epoch:  7
# EPOCH: 7
# Loss=0.6714001893997192 Batch_id=390 Accuracy=79.70: 100%|██████████| 391/391 [01:07<00:00,  5.76it/s]
# Test set: Average loss: 0.0038, Accuracy: 8297/10000 (82.97%)
#
# Validation accuracy increased (78.340000 --> 82.970000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  8
# EPOCH: 8
# Loss=0.6095378994941711 Batch_id=390 Accuracy=81.31: 100%|██████████| 391/391 [01:01<00:00,  6.33it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0050, Accuracy: 7945/10000 (79.45%)
#
# reducing
# Learning rate = 0.015  for epoch:  9
# EPOCH: 9
# Loss=0.5047550201416016 Batch_id=390 Accuracy=82.58: 100%|██████████| 391/391 [01:06<00:00,  5.88it/s]
# Test set: Average loss: 0.0040, Accuracy: 8365/10000 (83.65%)
#
# Validation accuracy increased (82.970000 --> 83.650000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  10
# EPOCH: 10
# Loss=0.609256386756897 Batch_id=390 Accuracy=83.25: 100%|██████████| 391/391 [01:06<00:00,  5.92it/s]
# Test set: Average loss: 0.0037, Accuracy: 8395/10000 (83.95%)
#
# Validation accuracy increased (83.650000 --> 83.950000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  11
# EPOCH: 11
# Loss=0.4919089674949646 Batch_id=390 Accuracy=84.40: 100%|██████████| 391/391 [01:03<00:00,  6.12it/s]
# Test set: Average loss: 0.0034, Accuracy: 8594/10000 (85.94%)
#
# Validation accuracy increased (83.950000 --> 85.940000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  12
# EPOCH: 12
# Loss=0.3200104236602783 Batch_id=390 Accuracy=85.18: 100%|██████████| 391/391 [01:06<00:00,  5.86it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0033, Accuracy: 8567/10000 (85.67%)
#
# reducing
# Learning rate = 0.015  for epoch:  13
# EPOCH: 13
# Loss=0.3498658537864685 Batch_id=390 Accuracy=85.96: 100%|██████████| 391/391 [01:03<00:00,  6.14it/s]
# Test set: Average loss: 0.0033, Accuracy: 8635/10000 (86.35%)
#
# Validation accuracy increased (85.940000 --> 86.350000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.015  for epoch:  14
# EPOCH: 14
# Loss=0.45807820558547974 Batch_id=390 Accuracy=86.81: 100%|██████████| 391/391 [01:05<00:00,  5.96it/s]
# Test set: Average loss: 0.0034, Accuracy: 8668/10000 (86.68%)
#
# Validation accuracy increased (86.350000 --> 86.680000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    14: reducing learning rate of group 0 to 1.5000e-03.
# reducing
# Learning rate = 0.0015  for epoch:  15
# EPOCH: 15
# Loss=0.20312254130840302 Batch_id=390 Accuracy=89.87: 100%|██████████| 391/391 [01:06<00:00,  5.90it/s]
# Test set: Average loss: 0.0025, Accuracy: 8976/10000 (89.76%)
#
# Validation accuracy increased (86.680000 --> 89.760000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.0015  for epoch:  16
# EPOCH: 16
# Loss=0.3397018313407898 Batch_id=390 Accuracy=90.72: 100%|██████████| 391/391 [01:03<00:00,  6.14it/s]
# Test set: Average loss: 0.0024, Accuracy: 8998/10000 (89.98%)
#
# Validation accuracy increased (89.760000 --> 89.980000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.0015  for epoch:  17
# EPOCH: 17
# Loss=0.30300578474998474 Batch_id=390 Accuracy=91.27: 100%|██████████| 391/391 [01:03<00:00,  6.15it/s]
# Test set: Average loss: 0.0024, Accuracy: 9009/10000 (90.09%)
#
# Validation accuracy increased (89.980000 --> 90.090000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.0015  for epoch:  18
# EPOCH: 18
# Loss=0.2596328556537628 Batch_id=390 Accuracy=91.33: 100%|██████████| 391/391 [01:07<00:00,  5.81it/s]
# Test set: Average loss: 0.0024, Accuracy: 9018/10000 (90.18%)
#
# Validation accuracy increased (90.090000 --> 90.180000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    18: reducing learning rate of group 0 to 1.5000e-04.
# reducing
# Learning rate = 0.00015000000000000001  for epoch:  19
# EPOCH: 19
# Loss=0.4998316168785095 Batch_id=390 Accuracy=91.61: 100%|██████████| 391/391 [01:09<00:00,  5.60it/s]
# Test set: Average loss: 0.0023, Accuracy: 9031/10000 (90.31%)
#
# Validation accuracy increased (90.180000 --> 90.310000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# reducing
# Learning rate = 0.00015000000000000001  for epoch:  20
# EPOCH: 20
# Loss=0.1361849009990692 Batch_id=390 Accuracy=91.71: 100%|██████████| 391/391 [01:10<00:00,  5.59it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9018/10000 (90.18%)
#
# reducing
# Learning rate = 0.00015000000000000001  for epoch:  21
# EPOCH: 21
# Loss=0.2708478271961212 Batch_id=390 Accuracy=91.71: 100%|██████████| 391/391 [01:07<00:00,  5.77it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9030/10000 (90.30%)
#
# Epoch    21: reducing learning rate of group 0 to 1.5000e-05.
# reducing
# Learning rate = 1.5000000000000002e-05  for epoch:  22
# EPOCH: 22
# Loss=0.2291399985551834 Batch_id=390 Accuracy=91.95: 100%|██████████| 391/391 [01:08<00:00,  5.68it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9022/10000 (90.22%)
#
# reducing
# Learning rate = 1.5000000000000002e-05  for epoch:  23
# EPOCH: 23
# Loss=0.23211053013801575 Batch_id=390 Accuracy=91.89: 100%|██████████| 391/391 [01:12<00:00,  5.43it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9023/10000 (90.23%)
#
# reducing
# Learning rate = 1.5000000000000002e-05  for epoch:  24
# EPOCH: 24
# Loss=0.24725477397441864 Batch_id=390 Accuracy=91.98: 100%|██████████| 391/391 [01:10<00:00,  5.51it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9026/10000 (90.26%)
#
# Epoch    24: reducing learning rate of group 0 to 1.5000e-06.
# reducing
# Learning rate = 1.5000000000000002e-06  for epoch:  25
# EPOCH: 25
# Loss=0.2970256209373474 Batch_id=390 Accuracy=91.85: 100%|██████████| 391/391 [01:08<00:00,  5.74it/s]
# Test set: Average loss: 0.0023, Accuracy: 9041/10000 (90.41%)
#
# Validation accuracy increased (90.310000 --> 90.410000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# increasing
# Learning rate = 1.5000000000000002e-06  for epoch:  26
# EPOCH: 26
# Loss=0.28793925046920776 Batch_id=390 Accuracy=91.85: 100%|██████████| 391/391 [01:11<00:00,  5.46it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9024/10000 (90.24%)
#
# increasing
# Learning rate = 1.5000000000000002e-06  for epoch:  27
# EPOCH: 27
# Loss=0.19867907464504242 Batch_id=390 Accuracy=92.01: 100%|██████████| 391/391 [01:03<00:00,  6.15it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9023/10000 (90.23%)
#
# increasing
# Learning rate = 1.5000000000000002e-06  for epoch:  28
# EPOCH: 28
# Loss=0.3064473271369934 Batch_id=390 Accuracy=92.12: 100%|██████████| 391/391 [01:06<00:00,  5.84it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9029/10000 (90.29%)
#
# increasing
# Epoch     4: reducing learning rate of group 0 to 1.5000e-08.
# Learning rate = 1.5000000000000002e-08  for epoch:  29
# EPOCH: 29
# Loss=0.21280264854431152 Batch_id=390 Accuracy=91.96: 100%|██████████| 391/391 [01:08<00:00,  5.72it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9028/10000 (90.28%)
#
# increasing
# Learning rate = 1.5000000000000002e-08  for epoch:  30
# EPOCH: 30
# Loss=0.19197480380535126 Batch_id=390 Accuracy=91.75: 100%|██████████| 391/391 [01:05<00:00,  5.96it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9022/10000 (90.22%)
#
# increasing
# Learning rate = 1.5000000000000002e-08  for epoch:  31
# EPOCH: 31
# Loss=0.15227898955345154 Batch_id=390 Accuracy=91.79: 100%|██████████| 391/391 [01:05<00:00,  5.96it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9034/10000 (90.34%)
#
# increasing
# Epoch     7: reducing learning rate of group 0 to 1.5000e-10.
# Learning rate = 1.5000000000000002e-10  for epoch:  32
# EPOCH: 32
# Loss=0.3271629810333252 Batch_id=390 Accuracy=91.83: 100%|██████████| 391/391 [01:05<00:00,  5.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9022/10000 (90.22%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  33
# EPOCH: 33
# Loss=0.1745050698518753 Batch_id=390 Accuracy=92.00: 100%|██████████| 391/391 [01:05<00:00,  5.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9023/10000 (90.23%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  34
# EPOCH: 34
# Loss=0.2292354553937912 Batch_id=390 Accuracy=91.98: 100%|██████████| 391/391 [01:05<00:00,  5.95it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9020/10000 (90.20%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  35
# EPOCH: 35
# Loss=0.20476455986499786 Batch_id=390 Accuracy=92.07: 100%|██████████| 391/391 [01:05<00:00,  5.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9025/10000 (90.25%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  36
# EPOCH: 36
# Loss=0.2686372697353363 Batch_id=390 Accuracy=91.93: 100%|██████████| 391/391 [01:05<00:00,  5.96it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9019/10000 (90.19%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  37
# EPOCH: 37
# Loss=0.2520310878753662 Batch_id=390 Accuracy=92.06: 100%|██████████| 391/391 [01:05<00:00,  5.96it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9031/10000 (90.31%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  38
# EPOCH: 38
# Loss=0.33320352435112 Batch_id=390 Accuracy=91.84: 100%|██████████| 391/391 [01:05<00:00,  5.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9036/10000 (90.36%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  39
# EPOCH: 39
# Loss=0.1296442300081253 Batch_id=390 Accuracy=92.13: 100%|██████████| 391/391 [01:05<00:00,  5.96it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9032/10000 (90.32%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  40
# EPOCH: 40
# Loss=0.24132947623729706 Batch_id=390 Accuracy=91.87: 100%|██████████| 391/391 [01:05<00:00,  5.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9036/10000 (90.36%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  41
# EPOCH: 41
# Loss=0.2632301449775696 Batch_id=390 Accuracy=91.86: 100%|██████████| 391/391 [01:05<00:00,  5.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9025/10000 (90.25%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  42
# EPOCH: 42
# Loss=0.20299682021141052 Batch_id=390 Accuracy=92.03: 100%|██████████| 391/391 [01:05<00:00,  5.96it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9024/10000 (90.24%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  43
# EPOCH: 43
# Loss=0.17460718750953674 Batch_id=390 Accuracy=91.93: 100%|██████████| 391/391 [01:05<00:00,  5.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9026/10000 (90.26%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  44
# EPOCH: 44
# Loss=0.39624595642089844 Batch_id=390 Accuracy=91.87: 100%|██████████| 391/391 [01:05<00:00,  5.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9035/10000 (90.35%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  45
# EPOCH: 45
# Loss=0.3002605736255646 Batch_id=390 Accuracy=92.00: 100%|██████████| 391/391 [01:05<00:00,  5.99it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0024, Accuracy: 9023/10000 (90.23%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  46
# EPOCH: 46
# Loss=0.3154786229133606 Batch_id=390 Accuracy=91.98: 100%|██████████| 391/391 [01:07<00:00,  5.78it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9035/10000 (90.35%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  47
# EPOCH: 47
# Loss=0.23550823330879211 Batch_id=390 Accuracy=91.79: 100%|██████████| 391/391 [01:05<00:00,  6.00it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9037/10000 (90.37%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  48
# EPOCH: 48
# Loss=0.23725073039531708 Batch_id=390 Accuracy=91.81: 100%|██████████| 391/391 [01:05<00:00,  6.00it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9025/10000 (90.25%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  49
# EPOCH: 49
# Loss=0.19136185944080353 Batch_id=390 Accuracy=91.94: 100%|██████████| 391/391 [01:05<00:00,  5.93it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0023, Accuracy: 9026/10000 (90.26%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  50
# EPOCH: 50
# Loss=0.2611722946166992 Batch_id=390 Accuracy=91.77: 100%|██████████| 391/391 [01:09<00:00,  5.66it/s]
# Test set: Average loss: 0.0024, Accuracy: 9026/10000 (90.26%)
#
# increasing
# Learning rate = 1.5000000000000002e-10  for epoch:  51

# %%
import numpy as np
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Accuracy of airplane: 87% (3406/3911)
# Test Accuracy of automobile: 94% (3686/3909)
# Test Accuracy of  bird: 81% (3251/4012)
# Test Accuracy of   cat: 74% (2956/3955)
# Test Accuracy of  deer: 85% (3350/3898)
# Test Accuracy of   dog: 81% (3161/3889)
# Test Accuracy of  frog: 88% (3560/4004)
# Test Accuracy of horse: 90% (3574/3963)
# Test Accuracy of  ship: 92% (3667/3972)
# Test Accuracy of truck: 92% (3695/3987)
#
# Test Accuracy (Overall): 86% (34306/39500)

# %%
# obtain one batch of test images
dataiterator = iter(test_loader)
plotdata.PlotData.plotmisclassifiedimages(dataiterator=dataiterator,model=cnn_model,classes=classes)

# %%
train_losses, train_acc = train_model.gettraindata()
test_losses, test_acc = train_model.gettestdata()
plotdata.PlotData.plottesttraingraph(train_losses=train_losses,train_acc=train_acc,test_losses=test_losses,
                                     test_acc=test_acc,lr_data=lr_data)

# %%
utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/finalmodelwithdata.pt",optimizer_state_dict=optimizer.state_dict
                      ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
                      test_losses=test_losses)
