# %% [markdown]
# # Import Libraries

# %%
import datetime
print("Model execution started at:" + datetime.datetime.today().ctime())
# Out:
# Model execution started at:Sun Mar  8 11:25:00 2020

# %%
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
import src.preprocessing.preprocessing as preprocessing
import src.utils.utils as utils
import src.models.train_model as train
import src.visualization.plotdata as plotdata
# %config IPCompleter.greedy=True

# %%
def printgpuinfo():
    gpu_info = !nvidia-smi
    gpu_info = '\n'.join(gpu_info)
    if gpu_info.find('failed') >= 0:
      print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
      print('and then re-execute this cell.')
    else:
      print(gpu_info)

# %%
def showsysteminfo():
    from psutil import virtual_memory
    ram_gb = virtual_memory().total / 1e9
    print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

    if ram_gb < 20:
      print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
      print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
      print('re-execute this cell.')
    else:
      print('You are using a high-RAM runtime!')

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
preproc = preprocessing.Preprocessing()
train_transforms = preproc.gettraintransforms()
test_transforms = preproc.gettesttransforms()

# %%
ds = dst.Dataset()
train_dataset = ds.gettraindataset(train_transforms)
test_dataset = ds.gettestdataset(test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 128
dataloader = dl.Cifar10Dataloader(traindataset=train_dataset, testdataset=test_dataset,batch_size=batch_size)
train_loader = dataloader.gettraindataloader()
test_loader = dataloader.gettestdataloader()
# Out:
# CUDA Available? True
# 128

# %%
# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

dataiterator = iter(train_loader)
plotdata.PlotData.showImagesfromdataset(dataiterator,classes=classes)

# %%
cnn_model, device = utils.Utils.createmodelresnet18()
train_model = train.TrainModel()
train_model.showmodelsummary(cnn_model)
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
optimizer = utils.Utils.createoptimizer(cnn_model, lr=0.01, momentum=0.9, weight_decay=0)
scheduler = utils.Utils.createscheduler(optimizer, mode='max', factor=0.1, patience=2,
                                        verbose=True)

# %%
lr_data = []
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
epochs = 51
for epoch in range(1, epochs):
    print("EPOCH:", epoch)
    train_model.train(cnn_model, device, train_loader, optimizer, 1)
    t_acc_epoch = train_model.test(cnn_model, device, test_loader, class_correct=class_correct,
                                   class_total=class_total, epoch=epoch)
    scheduler.step(t_acc_epoch)
    for param_groups in optimizer.param_groups:
        print("Learning rate =", param_groups['lr'], " for epoch: ", epoch + 1)  # print LR for different epochs
        lr_data.append(param_groups['lr'])
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 1
# /home/abhijit/.virtualenvs/dl4cv/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=1.124794602394104 Batch_id=390 Accuracy=48.87: 100%|██████████| 391/391 [01:17<00:00,  5.07it/s]
# Test set: Average loss: 0.0113, Accuracy: 5210/10000 (52.10%)
#
# Validation accuracy increased (0.000000 --> 52.100000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.03  for epoch:  2
# EPOCH: 2
# Loss=0.7459077835083008 Batch_id=390 Accuracy=67.84: 100%|██████████| 391/391 [01:25<00:00,  4.58it/s]
# Test set: Average loss: 0.0109, Accuracy: 5636/10000 (56.36%)
#
# Validation accuracy increased (52.100000 --> 56.360000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.03  for epoch:  3
# EPOCH: 3
# Loss=0.6378604173660278 Batch_id=390 Accuracy=76.03: 100%|██████████| 391/391 [01:39<00:00,  3.94it/s]
# Test set: Average loss: 0.0070, Accuracy: 7121/10000 (71.21%)
#
# Validation accuracy increased (56.360000 --> 71.210000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.03  for epoch:  4
# EPOCH: 4
# Loss=0.5585824251174927 Batch_id=390 Accuracy=80.23: 100%|██████████| 391/391 [01:41<00:00,  3.86it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0072, Accuracy: 7004/10000 (70.04%)
#
# Learning rate = 0.03  for epoch:  5
# EPOCH: 5
# Loss=0.5359441637992859 Batch_id=390 Accuracy=82.90: 100%|██████████| 391/391 [01:44<00:00,  3.75it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0077, Accuracy: 7043/10000 (70.43%)
#
# Epoch     5: reducing learning rate of group 0 to 3.0000e-03.
# Learning rate = 0.003  for epoch:  6
# EPOCH: 6
# Loss=0.29217472672462463 Batch_id=390 Accuracy=88.34: 100%|██████████| 391/391 [01:44<00:00,  3.73it/s]
# Test set: Average loss: 0.0049, Accuracy: 8028/10000 (80.28%)
#
# Validation accuracy increased (71.210000 --> 80.280000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.003  for epoch:  7
# EPOCH: 7
# Loss=0.2946488857269287 Batch_id=390 Accuracy=89.62: 100%|██████████| 391/391 [01:43<00:00,  3.77it/s]
# Test set: Average loss: 0.0051, Accuracy: 8035/10000 (80.35%)
#
# Validation accuracy increased (80.280000 --> 80.350000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.003  for epoch:  8
# EPOCH: 8
# Loss=0.2603863775730133 Batch_id=390 Accuracy=90.25: 100%|██████████| 391/391 [01:44<00:00,  3.75it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0050, Accuracy: 8009/10000 (80.09%)
#
# Epoch     8: reducing learning rate of group 0 to 3.0000e-04.
# Learning rate = 0.00030000000000000003  for epoch:  9
# EPOCH: 9
# Loss=0.27639251947402954 Batch_id=390 Accuracy=91.05: 100%|██████████| 391/391 [01:46<00:00,  3.67it/s]
# Test set: Average loss: 0.0047, Accuracy: 8109/10000 (81.09%)
#
# Validation accuracy increased (80.350000 --> 81.090000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.00030000000000000003  for epoch:  10
# EPOCH: 10
# Loss=0.2089967280626297 Batch_id=390 Accuracy=91.32: 100%|██████████| 391/391 [01:48<00:00,  3.59it/s]
# Test set: Average loss: 0.0046, Accuracy: 8130/10000 (81.30%)
#
# Validation accuracy increased (81.090000 --> 81.300000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.00030000000000000003  for epoch:  11
# EPOCH: 11
# Loss=0.2786380350589752 Batch_id=390 Accuracy=91.19: 100%|██████████| 391/391 [01:52<00:00,  3.48it/s]
# Test set: Average loss: 0.0047, Accuracy: 8146/10000 (81.46%)
#
# Validation accuracy increased (81.300000 --> 81.460000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    11: reducing learning rate of group 0 to 3.0000e-05.
# Learning rate = 3.0000000000000004e-05  for epoch:  12
# EPOCH: 12
# Loss=0.28465738892555237 Batch_id=390 Accuracy=91.47: 100%|██████████| 391/391 [01:44<00:00,  3.73it/s]
# Test set: Average loss: 0.0047, Accuracy: 8146/10000 (81.46%)
#
# Validation accuracy increased (81.460000 --> 81.460000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 3.0000000000000004e-05  for epoch:  13
# EPOCH: 13
# Loss=0.1881963014602661 Batch_id=390 Accuracy=91.49: 100%|██████████| 391/391 [01:48<00:00,  3.62it/s]
# Test set: Average loss: 0.0045, Accuracy: 8177/10000 (81.77%)
#
# Validation accuracy increased (81.460000 --> 81.770000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    13: reducing learning rate of group 0 to 3.0000e-06.
# Learning rate = 3.0000000000000005e-06  for epoch:  14
# EPOCH: 14
# Loss=0.41850775480270386 Batch_id=390 Accuracy=91.42: 100%|██████████| 391/391 [01:47<00:00,  3.65it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8165/10000 (81.65%)
#
# Learning rate = 3.0000000000000005e-06  for epoch:  15
# EPOCH: 15
# Loss=0.33765652775764465 Batch_id=390 Accuracy=91.39: 100%|██████████| 391/391 [01:48<00:00,  3.62it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8172/10000 (81.72%)
#
# Epoch    15: reducing learning rate of group 0 to 3.0000e-07.
# Learning rate = 3.000000000000001e-07  for epoch:  16
# EPOCH: 16
# Loss=0.14522267878055573 Batch_id=390 Accuracy=91.55: 100%|██████████| 391/391 [01:42<00:00,  3.80it/s]
# Test set: Average loss: 0.0045, Accuracy: 8189/10000 (81.89%)
#
# Validation accuracy increased (81.770000 --> 81.890000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 3.000000000000001e-07  for epoch:  17
# EPOCH: 17
# Loss=0.32247281074523926 Batch_id=390 Accuracy=91.48: 100%|██████████| 391/391 [01:40<00:00,  3.89it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8184/10000 (81.84%)
#
# Epoch    17: reducing learning rate of group 0 to 3.0000e-08.
# Learning rate = 3.000000000000001e-08  for epoch:  18
# EPOCH: 18
# Loss=0.3260241746902466 Batch_id=390 Accuracy=91.62: 100%|██████████| 391/391 [01:38<00:00,  3.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8165/10000 (81.65%)
#
# Learning rate = 3.000000000000001e-08  for epoch:  19
# EPOCH: 19
# Loss=0.31384366750717163 Batch_id=390 Accuracy=91.59: 100%|██████████| 391/391 [01:38<00:00,  3.98it/s]
# Test set: Average loss: 0.0045, Accuracy: 8193/10000 (81.93%)
#
# Validation accuracy increased (81.890000 --> 81.930000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 3.000000000000001e-08  for epoch:  20
# EPOCH: 20
# Loss=0.2054414302110672 Batch_id=390 Accuracy=91.36: 100%|██████████| 391/391 [01:38<00:00,  3.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0047, Accuracy: 8162/10000 (81.62%)
#
# Learning rate = 3.000000000000001e-08  for epoch:  21
# EPOCH: 21
# Loss=0.28306835889816284 Batch_id=390 Accuracy=91.43: 100%|██████████| 391/391 [01:37<00:00,  4.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8141/10000 (81.41%)
#
# Epoch    21: reducing learning rate of group 0 to 3.0000e-09.
# Learning rate = 3.0000000000000012e-09  for epoch:  22
# EPOCH: 22
# Loss=0.24907207489013672 Batch_id=390 Accuracy=91.55: 100%|██████████| 391/391 [01:36<00:00,  4.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8176/10000 (81.76%)
#
# Learning rate = 3.0000000000000012e-09  for epoch:  23
# EPOCH: 23
# Loss=0.3331373631954193 Batch_id=390 Accuracy=91.52: 100%|██████████| 391/391 [01:38<00:00,  3.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8169/10000 (81.69%)
#
# Learning rate = 3.0000000000000012e-09  for epoch:  24
# EPOCH: 24
# Loss=0.34438642859458923 Batch_id=390 Accuracy=91.55: 100%|██████████| 391/391 [01:40<00:00,  3.90it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8176/10000 (81.76%)
#
# Learning rate = 3.0000000000000012e-09  for epoch:  25
# EPOCH: 25
# Loss=0.2596609592437744 Batch_id=390 Accuracy=91.48: 100%|██████████| 391/391 [01:36<00:00,  4.04it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8148/10000 (81.48%)
#
# Learning rate = 3.0000000000000012e-09  for epoch:  26
# EPOCH: 26
# Loss=0.20123037695884705 Batch_id=390 Accuracy=91.44: 100%|██████████| 391/391 [01:38<00:00,  3.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8170/10000 (81.70%)
#
# Learning rate = 3.0000000000000012e-09  for epoch:  27
# EPOCH: 27
# Loss=0.24453261494636536 Batch_id=390 Accuracy=91.57: 100%|██████████| 391/391 [01:38<00:00,  3.99it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8177/10000 (81.77%)
#
# Learning rate = 3.0000000000000012e-09  for epoch:  28
# EPOCH: 28
# Loss=0.23708581924438477 Batch_id=390 Accuracy=91.42: 100%|██████████| 391/391 [01:37<00:00,  4.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8167/10000 (81.67%)
#
# Learning rate = 3.0000000000000012e-09  for epoch:  29
# EPOCH: 29
# Loss=0.2997828722000122 Batch_id=390 Accuracy=91.50: 100%|██████████| 391/391 [01:37<00:00,  4.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0047, Accuracy: 8141/10000 (81.41%)
#
# Learning rate = 3.0000000000000012e-09  for epoch:  30
# EPOCH: 30
# Loss=0.21575279533863068 Batch_id=307 Accuracy=91.52:  79%|███████▉  | 308/391 [01:18<00:19,  4.34it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7cea7cbc4cb0> in <module>
#       5 for epoch in range(1, epochs):
#       6     print("EPOCH:", epoch)
# ----> 7     train_model.train(cnn_model, device, train_loader, optimizer, 1)
#       8     t_acc_epoch = train_model.test(cnn_model, device, test_loader, class_correct=class_correct,
#       9                                    class_total=class_total, epoch=epoch)
#
# ~/EVARepo/EVA/A8/src/models/train_model.py in train(self, model, device, train_loader, optimizer, epoch)
#      60             # Update pbar-tqdm
#      61             pred = y_pred.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
# ---> 62             correct += pred.eq(target.view_as(pred)).sum().item()
#      63             processed += len(data)
#      64
#
# KeyboardInterrupt:

# %%
import numpy as np
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))

# %%
# obtain one batch of test images
dataiterator = iter(test_loader)
plotdata.PlotData.plotmisclassifiedimages(dataiterator=dataiterator,model=cnn_model,classes=classes)

# %%
train_losses, train_acc = train_model.gettraindata()
test_losses, test_acc = train_model.gettestdata()
plotdata.PlotData.plottesttraingraph(train_losses=train_losses,train_acc=train_acc,test_losses=test_losses,
                                     test_acc=test_acc,lr_data=lr_data)

# %%
utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/finalmodelwithdata.pt",optimizer_state_dict=optimizer.state_dict
                      ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
                      test_losses=test_losses)
