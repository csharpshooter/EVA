# %% [markdown]
# # Import Libraries

# %%
import datetime
print("Model execution started at:" + datetime.datetime.today().ctime())
# Out:
# Model execution started at:Sat Mar 21 01:52:08 2020

# %%
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
import src.preprocessing.albumentationstransforms as preprocessing
import src.utils.utils as utils
import src.models.train_model as train
import src.visualization.plotdata as plotdata
import src.preprocessing.customcompose as customcompose
from src.train.lrfinder.lrfinder import LRFinder
import src.train.train_model
# %config IPCompleter.greedy=True
# %reload_ext autoreload

# %%
# %autoreload 2  # Autoreload all modules

# %%
def printgpuinfo():
    gpu_info = !nvidia-smi
    gpu_info = '\n'.join(gpu_info)
    if gpu_info.find('failed') >= 0:
      print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
      print('and then re-execute this cell.')
    else:
      print(gpu_info)

# %%
def showsysteminfo():
    from psutil import virtual_memory
    ram_gb = virtual_memory().total / 1e9
    print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

    if ram_gb < 20:
      print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
      print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
      print('re-execute this cell.')
    else:
      print('You are using a high-RAM runtime!')

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
# mean,std= utils.Utils.calculatemeanandstddeviation()
# print("mean: " + str(mean))
# print("std: " + str(std))
mean=[0.5,0.5,0.5]
std=[0.5,0.5,0.5]
preproc = preprocessing.AlbumentaionsTransforms()
train_transforms = preproc.gettraintransforms(mean,std)
test_transforms = preproc.gettesttransforms(mean,std)
compose_train = customcompose.CustomCompose(train_transforms)
compose_test = customcompose.CustomCompose(test_transforms)

# %%
ds = dst.Dataset()
train_dataset = ds.gettraindataset(compose_train)
test_dataset = ds.gettestdataset(compose_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 128
dataloader = dl.Cifar10Dataloader(traindataset=train_dataset, testdataset=test_dataset,batch_size=batch_size)
train_loader = dataloader.gettraindataloader()
test_loader = dataloader.gettestdataloader()
# Out:
# CUDA Available? True
# 128

# %%
# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

#TODO show transformed images fom dataset
dataiterator = iter(train_loader)
plotdata.PlotData.showImagesfromdataset(dataiterator,classes=classes)

# %%
cnn_model, device = utils.Utils.createmodelresnet18()
train_model = train.TrainModel()
train_model.showmodelsummary(cnn_model)
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
optimizer = utils.Utils.createoptimizer(cnn_model, lr=0.01, momentum=0.9, weight_decay=0)
scheduler = utils.Utils.createscheduler(optimizer, mode='max', factor=0.5, patience=2,
                                        verbose=True)
criterion = torch.nn.CrossEntropyLoss()

# %%
lr_finder = LRFinder(cnn_model, optimizer, criterion, device="cuda")
lr_finder.range_test(train_loader, end_lr=100, num_iter=100, step_mode="exp")
lr_finder.plot()
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
lr_finder.reset()

# %%
lr_finder.range_test(train_loader, val_loader=test_loader, end_lr=100, num_iter=100, step_mode="exp")
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
lr_finder.plot(skip_end=0)

# %%
lr_finder.reset()

# %%
optimizer = utils.Utils.createoptimizer(cnn_model, lr=0.06, momentum=0.9, weight_decay=0)
scheduler = utils.Utils.createscheduler(optimizer, mode='max', factor=0.9, patience=2,
                                        verbose=True)

# %%
lr_data = []
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
epochs = 50
for epoch in range(1, epochs+1):
    print("EPOCH:", epoch)
    train_model.train(cnn_model, device, train_loader, optimizer, 1)
    t_acc_epoch = train_model.test(cnn_model, device, test_loader, class_correct=class_correct,
                                   class_total=class_total, epoch=epoch)
    scheduler.step(t_acc_epoch)
    for param_groups in optimizer.param_groups:
        print("Learning rate =", param_groups['lr'], " for epoch: ", epoch + 1)  # print LR for different epochs
        lr_data.append(param_groups['lr'])
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 1
# /home/abhijit/.virtualenvs/dl4cv/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=1.3753716945648193 Batch_id=390 Accuracy=39.37: 100%|██████████| 391/391 [01:40<00:00,  3.90it/s]
# Test set: Average loss: 0.0102, Accuracy: 5205/10000 (52.05%)
#
# Validation accuracy increased (0.000000 --> 52.050000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  2
# EPOCH: 2
# Loss=1.155717372894287 Batch_id=390 Accuracy=56.62: 100%|██████████| 391/391 [01:55<00:00,  3.38it/s]
# Test set: Average loss: 0.0085, Accuracy: 6357/10000 (63.57%)
#
# Validation accuracy increased (52.050000 --> 63.570000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  3
# EPOCH: 3
# Loss=0.9124361276626587 Batch_id=390 Accuracy=65.38: 100%|██████████| 391/391 [01:51<00:00,  3.50it/s]
# Test set: Average loss: 0.0071, Accuracy: 6841/10000 (68.41%)
#
# Validation accuracy increased (63.570000 --> 68.410000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  4
# EPOCH: 4
# Loss=0.8056380152702332 Batch_id=390 Accuracy=71.84: 100%|██████████| 391/391 [01:54<00:00,  3.41it/s]
# Test set: Average loss: 0.0056, Accuracy: 7495/10000 (74.95%)
#
# Validation accuracy increased (68.410000 --> 74.950000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  5
# EPOCH: 5
# Loss=0.9582706689834595 Batch_id=390 Accuracy=75.87: 100%|██████████| 391/391 [01:59<00:00,  3.26it/s]
# Test set: Average loss: 0.0053, Accuracy: 7665/10000 (76.65%)
#
# Validation accuracy increased (74.950000 --> 76.650000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  6
# EPOCH: 6
# Loss=0.39635008573532104 Batch_id=390 Accuracy=78.87: 100%|██████████| 391/391 [01:55<00:00,  3.38it/s]
# Test set: Average loss: 0.0046, Accuracy: 8021/10000 (80.21%)
#
# Validation accuracy increased (76.650000 --> 80.210000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  7
# EPOCH: 7
# Loss=0.7138440012931824 Batch_id=390 Accuracy=81.86: 100%|██████████| 391/391 [01:55<00:00,  3.39it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0051, Accuracy: 7894/10000 (78.94%)
#
# Learning rate = 0.06  for epoch:  8
# EPOCH: 8
# Loss=0.3202645182609558 Batch_id=390 Accuracy=83.90: 100%|██████████| 391/391 [01:58<00:00,  3.30it/s]
# Test set: Average loss: 0.0044, Accuracy: 8149/10000 (81.49%)
#
# Validation accuracy increased (80.210000 --> 81.490000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  9
# EPOCH: 9
# Loss=0.31776267290115356 Batch_id=390 Accuracy=85.68: 100%|██████████| 391/391 [02:01<00:00,  3.23it/s]
# Test set: Average loss: 0.0044, Accuracy: 8171/10000 (81.71%)
#
# Validation accuracy increased (81.490000 --> 81.710000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  10
# EPOCH: 10
# Loss=0.18867945671081543 Batch_id=390 Accuracy=87.36: 100%|██████████| 391/391 [01:53<00:00,  3.44it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0047, Accuracy: 8086/10000 (80.86%)
#
# Learning rate = 0.06  for epoch:  11
# EPOCH: 11
# Loss=0.4190293252468109 Batch_id=390 Accuracy=89.24: 100%|██████████| 391/391 [01:55<00:00,  3.38it/s]
# Test set: Average loss: 0.0042, Accuracy: 8371/10000 (83.71%)
#
# Validation accuracy increased (81.710000 --> 83.710000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  12
# EPOCH: 12
# Loss=0.2931364178657532 Batch_id=390 Accuracy=90.24: 100%|██████████| 391/391 [01:57<00:00,  3.32it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0043, Accuracy: 8334/10000 (83.34%)
#
# Learning rate = 0.06  for epoch:  13
# EPOCH: 13
# Loss=0.19378161430358887 Batch_id=390 Accuracy=91.42: 100%|██████████| 391/391 [01:58<00:00,  3.30it/s]
# Test set: Average loss: 0.0044, Accuracy: 8392/10000 (83.92%)
#
# Validation accuracy increased (83.710000 --> 83.920000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  14
# EPOCH: 14
# Loss=0.27263015508651733 Batch_id=390 Accuracy=92.52: 100%|██████████| 391/391 [01:52<00:00,  3.49it/s]
# Test set: Average loss: 0.0044, Accuracy: 8406/10000 (84.06%)
#
# Validation accuracy increased (83.920000 --> 84.060000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    14: reducing learning rate of group 0 to 5.4000e-02.
# Learning rate = 0.054  for epoch:  15
# EPOCH: 15
# Loss=0.1087150126695633 Batch_id=390 Accuracy=93.86: 100%|██████████| 391/391 [01:55<00:00,  3.39it/s]
# Test set: Average loss: 0.0045, Accuracy: 8454/10000 (84.54%)
#
# Validation accuracy increased (84.060000 --> 84.540000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.054  for epoch:  16
# EPOCH: 16
# Loss=0.20863254368305206 Batch_id=390 Accuracy=94.48: 100%|██████████| 391/391 [01:54<00:00,  3.40it/s]
# Test set: Average loss: 0.0045, Accuracy: 8471/10000 (84.71%)
#
# Validation accuracy increased (84.540000 --> 84.710000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.054  for epoch:  17
# EPOCH: 17
# Loss=0.08683046698570251 Batch_id=390 Accuracy=95.14: 100%|██████████| 391/391 [01:52<00:00,  3.49it/s]
# Test set: Average loss: 0.0047, Accuracy: 8472/10000 (84.72%)
#
# Validation accuracy increased (84.710000 --> 84.720000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.054  for epoch:  18
# EPOCH: 18
# Loss=0.21343326568603516 Batch_id=390 Accuracy=95.80: 100%|██████████| 391/391 [01:52<00:00,  3.46it/s]
# Test set: Average loss: 0.0048, Accuracy: 8482/10000 (84.82%)
#
# Validation accuracy increased (84.720000 --> 84.820000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.054  for epoch:  19
# EPOCH: 19
# Loss=0.15656088292598724 Batch_id=390 Accuracy=96.02: 100%|██████████| 391/391 [01:55<00:00,  3.40it/s]
# Test set: Average loss: 0.0048, Accuracy: 8508/10000 (85.08%)
#
# Validation accuracy increased (84.820000 --> 85.080000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    19: reducing learning rate of group 0 to 4.8600e-02.
# Learning rate = 0.0486  for epoch:  20
# EPOCH: 20
# Loss=0.11976374685764313 Batch_id=390 Accuracy=96.75: 100%|██████████| 391/391 [01:57<00:00,  3.34it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 8487/10000 (84.87%)
#
# Learning rate = 0.0486  for epoch:  21
# EPOCH: 21
# Loss=0.047718994319438934 Batch_id=390 Accuracy=97.12: 100%|██████████| 391/391 [01:53<00:00,  3.44it/s]
# Test set: Average loss: 0.0050, Accuracy: 8539/10000 (85.39%)
#
# Validation accuracy increased (85.080000 --> 85.390000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.0486  for epoch:  22
# EPOCH: 22
# Loss=0.057130116969347 Batch_id=390 Accuracy=97.21: 100%|██████████| 391/391 [01:53<00:00,  3.43it/s]
# Test set: Average loss: 0.0052, Accuracy: 8542/10000 (85.42%)
#
# Validation accuracy increased (85.390000 --> 85.420000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    22: reducing learning rate of group 0 to 4.3740e-02.
# Learning rate = 0.04374  for epoch:  23
# EPOCH: 23
# Loss=0.06724699586629868 Batch_id=390 Accuracy=97.86: 100%|██████████| 391/391 [01:53<00:00,  3.45it/s]
# Test set: Average loss: 0.0053, Accuracy: 8611/10000 (86.11%)
#
# Validation accuracy increased (85.420000 --> 86.110000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.04374  for epoch:  24
# EPOCH: 24
# Loss=0.06545590609312057 Batch_id=390 Accuracy=98.06: 100%|██████████| 391/391 [01:55<00:00,  3.38it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0054, Accuracy: 8569/10000 (85.69%)
#
# Learning rate = 0.04374  for epoch:  25
# EPOCH: 25
# Loss=0.023275136947631836 Batch_id=390 Accuracy=98.19: 100%|██████████| 391/391 [01:59<00:00,  3.28it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0055, Accuracy: 8573/10000 (85.73%)
#
# Learning rate = 0.04374  for epoch:  26
# EPOCH: 26
# Loss=0.045337896794080734 Batch_id=390 Accuracy=98.15: 100%|██████████| 391/391 [01:57<00:00,  3.31it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0057, Accuracy: 8552/10000 (85.52%)
#
# Epoch    26: reducing learning rate of group 0 to 3.9366e-02.
# Learning rate = 0.039366000000000005  for epoch:  27
# EPOCH: 27
# Loss=0.08820351213216782 Batch_id=390 Accuracy=98.56: 100%|██████████| 391/391 [02:02<00:00,  3.19it/s]
# Test set: Average loss: 0.0056, Accuracy: 8632/10000 (86.32%)
#
# Validation accuracy increased (86.110000 --> 86.320000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.039366000000000005  for epoch:  28
# EPOCH: 28
# Loss=0.012392413802444935 Batch_id=390 Accuracy=98.46: 100%|██████████| 391/391 [01:57<00:00,  3.34it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 8599/10000 (85.99%)
#
# Learning rate = 0.039366000000000005  for epoch:  29
# EPOCH: 29
# Loss=0.03515341132879257 Batch_id=390 Accuracy=98.64: 100%|██████████| 391/391 [01:56<00:00,  3.36it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0056, Accuracy: 8596/10000 (85.96%)
#
# Epoch    29: reducing learning rate of group 0 to 3.5429e-02.
# Learning rate = 0.03542940000000001  for epoch:  30
# EPOCH: 30
# Loss=0.1407478302717209 Batch_id=390 Accuracy=98.78: 100%|██████████| 391/391 [01:58<00:00,  3.29it/s]
# Test set: Average loss: 0.0052, Accuracy: 8662/10000 (86.62%)
#
# Validation accuracy increased (86.320000 --> 86.620000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.03542940000000001  for epoch:  31
# EPOCH: 31
# Loss=0.018167991191148758 Batch_id=390 Accuracy=98.96: 100%|██████████| 391/391 [01:57<00:00,  3.31it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0055, Accuracy: 8636/10000 (86.36%)
#
# Learning rate = 0.03542940000000001  for epoch:  32
# EPOCH: 32
# Loss=0.008900034241378307 Batch_id=390 Accuracy=98.95: 100%|██████████| 391/391 [02:01<00:00,  3.23it/s]
# Test set: Average loss: 0.0056, Accuracy: 8668/10000 (86.68%)
#
# Validation accuracy increased (86.620000 --> 86.680000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    32: reducing learning rate of group 0 to 3.1886e-02.
# Learning rate = 0.031886460000000005  for epoch:  33
# EPOCH: 33
# Loss=0.025097930803894997 Batch_id=390 Accuracy=99.09: 100%|██████████| 391/391 [01:59<00:00,  3.28it/s]
# Test set: Average loss: 0.0056, Accuracy: 8705/10000 (87.05%)
#
# Validation accuracy increased (86.680000 --> 87.050000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.031886460000000005  for epoch:  34
# EPOCH: 34
# Loss=0.045962948352098465 Batch_id=390 Accuracy=99.20: 100%|██████████| 391/391 [02:02<00:00,  3.20it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0058, Accuracy: 8633/10000 (86.33%)
#
# Learning rate = 0.031886460000000005  for epoch:  35
# EPOCH: 35
# Loss=0.021110743284225464 Batch_id=390 Accuracy=99.21: 100%|██████████| 391/391 [01:59<00:00,  3.27it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0059, Accuracy: 8641/10000 (86.41%)
#
# Learning rate = 0.031886460000000005  for epoch:  36
# EPOCH: 36
# Loss=0.0019619823433458805 Batch_id=390 Accuracy=99.16: 100%|██████████| 391/391 [02:01<00:00,  3.21it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0056, Accuracy: 8663/10000 (86.63%)
#
# Epoch    36: reducing learning rate of group 0 to 2.8698e-02.
# Learning rate = 0.028697814000000006  for epoch:  37
# EPOCH: 37
# Loss=0.055903900414705276 Batch_id=390 Accuracy=99.34: 100%|██████████| 391/391 [02:00<00:00,  3.26it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0059, Accuracy: 8646/10000 (86.46%)
#
# Learning rate = 0.028697814000000006  for epoch:  38
# EPOCH: 38
# Loss=0.00207784166559577 Batch_id=390 Accuracy=99.42: 100%|██████████| 391/391 [02:03<00:00,  3.17it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0058, Accuracy: 8674/10000 (86.74%)
#
# Learning rate = 0.028697814000000006  for epoch:  39
# EPOCH: 39
# Loss=0.003924894146621227 Batch_id=390 Accuracy=99.38: 100%|██████████| 391/391 [02:06<00:00,  3.09it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0057, Accuracy: 8698/10000 (86.98%)
#
# Epoch    39: reducing learning rate of group 0 to 2.5828e-02.
# Learning rate = 0.025828032600000005  for epoch:  40
# EPOCH: 40
# Loss=0.0024049163330346346 Batch_id=390 Accuracy=99.43: 100%|██████████| 391/391 [02:04<00:00,  3.14it/s]
# Test set: Average loss: 0.0058, Accuracy: 8708/10000 (87.08%)
#
# Validation accuracy increased (87.050000 --> 87.080000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.025828032600000005  for epoch:  41
# EPOCH: 41
# Loss=0.0032304166816174984 Batch_id=390 Accuracy=99.56: 100%|██████████| 391/391 [02:03<00:00,  3.17it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0061, Accuracy: 8678/10000 (86.78%)
#
# Learning rate = 0.025828032600000005  for epoch:  42
# EPOCH: 42
# Loss=0.07606383413076401 Batch_id=390 Accuracy=99.42: 100%|██████████| 391/391 [02:03<00:00,  3.17it/s]
# Test set: Average loss: 0.0059, Accuracy: 8713/10000 (87.13%)
#
# Validation accuracy increased (87.080000 --> 87.130000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Epoch    42: reducing learning rate of group 0 to 2.3245e-02.
# Learning rate = 0.023245229340000007  for epoch:  43
# EPOCH: 43
# Loss=0.0009191512945108116 Batch_id=390 Accuracy=99.55: 100%|██████████| 391/391 [01:58<00:00,  3.30it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0062, Accuracy: 8705/10000 (87.05%)
#
# Learning rate = 0.023245229340000007  for epoch:  44
# EPOCH: 44
# Loss=0.048363249748945236 Batch_id=390 Accuracy=99.56: 100%|██████████| 391/391 [01:58<00:00,  3.29it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0062, Accuracy: 8665/10000 (86.65%)
#
# Learning rate = 0.023245229340000007  for epoch:  45
# EPOCH: 45
# Loss=0.06595994532108307 Batch_id=390 Accuracy=99.57: 100%|██████████| 391/391 [01:59<00:00,  3.28it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0061, Accuracy: 8686/10000 (86.86%)
#
# Epoch    45: reducing learning rate of group 0 to 2.0921e-02.
# Learning rate = 0.020920706406000005  for epoch:  46
# EPOCH: 46
# Loss=0.008259844966232777 Batch_id=390 Accuracy=99.62: 100%|██████████| 391/391 [01:57<00:00,  3.33it/s]
# Test set: Average loss: 0.0062, Accuracy: 8719/10000 (87.19%)
#
# Validation accuracy increased (87.130000 --> 87.190000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.020920706406000005  for epoch:  47
# EPOCH: 47
# Loss=0.004660499282181263 Batch_id=390 Accuracy=99.65: 100%|██████████| 391/391 [02:00<00:00,  3.26it/s]
# Test set: Average loss: 0.0059, Accuracy: 8735/10000 (87.35%)
#
# Validation accuracy increased (87.190000 --> 87.350000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.020920706406000005  for epoch:  48
# EPOCH: 48
# Loss=0.01576387882232666 Batch_id=390 Accuracy=99.72: 100%|██████████| 391/391 [02:01<00:00,  3.23it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0062, Accuracy: 8700/10000 (87.00%)
#
# Epoch    48: reducing learning rate of group 0 to 1.8829e-02.
# Learning rate = 0.018828635765400004  for epoch:  49
# EPOCH: 49
# Loss=0.02621295489370823 Batch_id=390 Accuracy=99.68: 100%|██████████| 391/391 [02:00<00:00,  3.25it/s]
# Test set: Average loss: 0.0062, Accuracy: 8740/10000 (87.40%)
#
# Validation accuracy increased (87.350000 --> 87.400000).  Saving model ...
#   0%|          | 0/391 [00:00<?, ?it/s]
# Learning rate = 0.018828635765400004  for epoch:  50
# EPOCH: 50
# Loss=0.0011106848251074553 Batch_id=390 Accuracy=99.69: 100%|██████████| 391/391 [02:00<00:00,  3.26it/s]
# Test set: Average loss: 0.0062, Accuracy: 8722/10000 (87.22%)
#
# Learning rate = 0.018828635765400004  for epoch:  51

# %%
import numpy as np
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Accuracy of airplane: 84% (3330/3941)
# Test Accuracy of automobile: 92% (3748/4052)
# Test Accuracy of  bird: 78% (3124/3967)
# Test Accuracy of   cat: 68% (2748/3994)
# Test Accuracy of  deer: 81% (3231/3985)
# Test Accuracy of   dog: 73% (2870/3893)
# Test Accuracy of  frog: 87% (3460/3970)
# Test Accuracy of horse: 87% (3436/3916)
# Test Accuracy of  ship: 91% (3565/3887)
# Test Accuracy of truck: 91% (3554/3895)
#
# Test Accuracy (Overall): 83% (33066/39500)

# %%
# obtain one batch of test images
dataiterator = iter(test_loader)
plotdata.PlotData.plotmisclassifiedimages(dataiterator=dataiterator,model=cnn_model,classes=classes,
                                          batch_size=batch_size)

# %%
train_losses, train_acc = train_model.gettraindata()
test_losses, test_acc = train_model.gettestdata()
plotdata.PlotData.plottesttraingraph(train_losses=train_losses,train_acc=train_acc,test_losses=test_losses,
                                     test_acc=test_acc,lr_data=lr_data)

# %%
utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/finalmodelwithdata.pt",optimizer_state_dict=optimizer.state_dict
                      ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
                      test_losses=test_losses)

# %%
import torch
import src.utils.utils as utils
print(torch.cuda.is_available())
saved_data = utils.Utils.loadmodel(path="savedmodels/finalmodelwithdata.pt")
# Out:
# True

# %%
model, device = utils.Utils.createmodelresnet18()
model.load_state_dict(state_dict=saved_data['model_state_dict'])
# Out:
# cuda
# <All keys matched successfully>

# %%
import glob
from PIL import Image
from src.utils.modelutils import ModelUtils

image_paths = glob.glob('./images/testimages/*.*')
images = list(map(lambda x: Image.open(x), image_paths))
ModelUtils.subplot(images, title='inputs', nrows=2, ncols=5)

# %%
import torchvision

inputs = [torchvision.transforms.Compose([torchvision.transforms.Resize((32, 32)), torchvision.transforms.ToTensor(),
                                          torchvision.transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])(
    x).unsqueeze(0) for x in images]  # add 1 dim for batch
inputs = [i.to(device) for i in inputs]

# %%
from src.visualization.gradcam.gradcam import gradcamof

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

gradcamof(model,inputs,classes)
# Out:
# airplane
# bird
# bird
# airplane
# cat
# airplane
# truck
# horse
# automobile
# cat
