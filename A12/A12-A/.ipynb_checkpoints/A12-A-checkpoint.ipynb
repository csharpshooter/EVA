# %% [markdown]
# # Import Libraries

# %%
import datetime
print("Model execution started at:" + datetime.datetime.today().ctime())
# Out:
# Model execution started at:Thu Apr 16 17:38:27 2020

# %%
import src
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
import src.utils.utils as utils
import src.train.train_model as train
import src.visualization.plotdata as plotdata
import src.preprocessing.preprochelper as preprochelper
from src.utils import cifar_mean,cifar_std
from src.dataset.tinyimagenethelper import TinyImagenetHelper
import torchvision

# %config IPCompleter.greedy=True
# %reload_ext autoreload

# %%
# %autoreload 2  # Autoreload all modules

# %%
def printgpuinfo():
    gpu_info = !nvidia-smi
    gpu_info = '\n'.join(gpu_info)
    if gpu_info.find('failed') >= 0:
      print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
      print('and then re-execute this cell.')
    else:
      print(gpu_info)
    
printgpuinfo()

# %%
def showsysteminfo():
    from psutil import virtual_memory
    ram_gb = virtual_memory().total / 1e9
    ram_gb_avail = virtual_memory().available / 1e9
    ram_gb_used = virtual_memory().active / 1e9
    print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
    print('Your runtime has {:.1f} gigabytes of free RAM\n'.format(ram_gb_avail))
    print('Your runtime has {:.1f} gigabytes of used RAM\n'.format(ram_gb_used))    
showsysteminfo()

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
batch_size = 512
helper = TinyImagenetHelper()

path = helper.download_dataset(folder_path="data")
dict = helper.get_id_dictionary(path=path)
values, classes = helper.get_class_to_id_dict(id_dict=dict, path=path)

train_data, train_label, test_data, test_label = helper.get_train_test_labels_data(dict, path)
# calculated mean and std dev values for tiny imagenet takes lot of RAM so not calculating every time
# mean = [0.48043722, 0.44820285, 0.39760238]
# stddev = [0.27698976, 0.26908714, 0.2821603]
# mean, std = utils.Utils.calculate_mean_std_deviation(train_data, test_data)

# mean_timgnet = [0.48043722, 0.44820285, 0.39760238]
# std_timgnet = [0.27698976, 0.26908714, 0.2821603]
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225] 
# batch_size = 64
# compose_train, compose_test = preprochelper.PreprocHelper.getalbumentationstraintesttransforms(mean,std)

train_transforms, test_transforms = preprochelper.PreprocHelper.getpytorchtransforms(mean, std)

ds = dst.Dataset()
# train_dataset = ds.gettraindataset(train_transforms)
# test_dataset = ds.gettestdataset(test_transforms)

train_dataset = ds.get_tiny_imagenet_train_dataset(train_image_data=train_data, train_image_labels=train_label,
                                                   train_transforms=train_transforms)

test_dataset = ds.get_tiny_imagenet_test_dataset(test_image_labels=test_label, test_image_data=test_data,
                                                 test_transforms=test_transforms)

dataloader = dl.Dataloader(traindataset=train_dataset, testdataset=test_dataset, batch_size=batch_size)
train_loader = dataloader.gettraindataloader()
test_loader = dataloader.gettestdataloader()

# specify the image classes
# classes = ds.getclassesinCIFAR10dataset()
data_iterator = iter(train_loader)
plotdata.PlotData.showImagesfromdataset(data_iterator, classes=classes)
# Out:
# File: tiny-imagenet-200.zip already downloaded.
# File: tiny-imagenet-200 already extracted.
# 100%|██████████| 200/200 [00:00<00:00, 2838.82it/s]
# 10000it [00:00, 892348.15it/s]
# Starting data loading
# Finished data loading, in 0.08507037162780762 seconds
# CUDA Available? True
# 512
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

cnn_model = torchvision.models.resnet18(pretrained=False, num_classes=200).to(device)
train_model = train.TrainModel()
train_model.showmodelsummary(cnn_model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#               ReLU-7             [-1, 64, 8, 8]               0
#             Conv2d-8             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-9             [-1, 64, 8, 8]             128
#              ReLU-10             [-1, 64, 8, 8]               0
#        BasicBlock-11             [-1, 64, 8, 8]               0
#            Conv2d-12             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-13             [-1, 64, 8, 8]             128
#              ReLU-14             [-1, 64, 8, 8]               0
#            Conv2d-15             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-16             [-1, 64, 8, 8]             128
#              ReLU-17             [-1, 64, 8, 8]               0
#        BasicBlock-18             [-1, 64, 8, 8]               0
#            Conv2d-19            [-1, 128, 4, 4]          73,728
#       BatchNorm2d-20            [-1, 128, 4, 4]             256
#              ReLU-21            [-1, 128, 4, 4]               0
#            Conv2d-22            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-23            [-1, 128, 4, 4]             256
#            Conv2d-24            [-1, 128, 4, 4]           8,192
#       BatchNorm2d-25            [-1, 128, 4, 4]             256
#              ReLU-26            [-1, 128, 4, 4]               0
#        BasicBlock-27            [-1, 128, 4, 4]               0
#            Conv2d-28            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-29            [-1, 128, 4, 4]             256
#              ReLU-30            [-1, 128, 4, 4]               0
#            Conv2d-31            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-32            [-1, 128, 4, 4]             256
#              ReLU-33            [-1, 128, 4, 4]               0
#        BasicBlock-34            [-1, 128, 4, 4]               0
#            Conv2d-35            [-1, 256, 2, 2]         294,912
#       BatchNorm2d-36            [-1, 256, 2, 2]             512
#              ReLU-37            [-1, 256, 2, 2]               0
#            Conv2d-38            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-39            [-1, 256, 2, 2]             512
#            Conv2d-40            [-1, 256, 2, 2]          32,768
#       BatchNorm2d-41            [-1, 256, 2, 2]             512
#              ReLU-42            [-1, 256, 2, 2]               0
#        BasicBlock-43            [-1, 256, 2, 2]               0
#            Conv2d-44            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-45            [-1, 256, 2, 2]             512
#              ReLU-46            [-1, 256, 2, 2]               0
#            Conv2d-47            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-48            [-1, 256, 2, 2]             512
#              ReLU-49            [-1, 256, 2, 2]               0
#        BasicBlock-50            [-1, 256, 2, 2]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                  [-1, 200]         102,600
# ================================================================
# Total params: 11,279,112
# Trainable params: 11,279,112
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.29
# Params size (MB): 43.03
# Estimated Total Size (MB): 44.32
# ----------------------------------------------------------------

# %%
epochs = 25

# %%
from torch.optim.lr_scheduler import LambdaLR
optimizer = utils.Utils.createoptimizer(cnn_model, lr=0.01, momentum=0.9, weight_decay=0, nesterov=True)
lambda1 = lambda epoch: (epoch * 0.4)
scheduler = LambdaLR(optimizer, lr_lambda=[lambda1])

# %%
lr_data = []
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

for epoch in range(1, epochs+1):
    print("EPOCH:", epoch)
    train_model.train(cnn_model, device, train_loader, optimizer, 1)
    t_acc_epoch = train_model.test(model=cnn_model, device=device, test_loader=test_loader, class_correct=class_correct,
                                   class_total=class_total, epoch=epoch, lr_data=lr_data)
#     scheduler.step(t_acc_epoch)
    scheduler.step()
    for param_groups in optimizer.param_groups:
        print("Learning rate =", param_groups['lr'], " for epoch: ", epoch + 1)  # print LR for different epochs
        lr_data.append(param_groups['lr'])
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 1
# /home/abhijit/.virtualenvs/dl4cv/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=5.400017738342285 Batch_id=150 Accuracy=0.45: 100%|██████████| 151/151 [00:35<00:00,  4.21it/s]
# Test set: Average loss: 0.0107, Accuracy: 168/33000 (0.51%)
#
# Validation accuracy increased (0.000000 --> 0.509091).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.004  for epoch:  2
# EPOCH: 2
# Loss=5.070986747741699 Batch_id=150 Accuracy=1.45: 100%|██████████| 151/151 [00:42<00:00,  3.53it/s]
# Test set: Average loss: 0.0099, Accuracy: 968/33000 (2.93%)
#
# Validation accuracy increased (0.509091 --> 2.933333).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.008  for epoch:  3
# EPOCH: 3
# Loss=4.575749397277832 Batch_id=150 Accuracy=4.71: 100%|██████████| 151/151 [01:03<00:00,  2.39it/s]
# Test set: Average loss: 0.0091, Accuracy: 2218/33000 (6.72%)
#
# Validation accuracy increased (2.933333 --> 6.721212).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.012000000000000002  for epoch:  4
# EPOCH: 4
# Loss=4.319791793823242 Batch_id=150 Accuracy=8.51: 100%|██████████| 151/151 [01:15<00:00,  1.99it/s]
# Test set: Average loss: 0.0086, Accuracy: 3254/33000 (9.86%)
#
# Validation accuracy increased (6.721212 --> 9.860606).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.016  for epoch:  5
# EPOCH: 5
# Loss=3.836097478866577 Batch_id=150 Accuracy=12.54: 100%|██████████| 151/151 [01:21<00:00,  1.85it/s]
# Test set: Average loss: 0.0079, Accuracy: 4767/33000 (14.45%)
#
# Validation accuracy increased (9.860606 --> 14.445455).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.02  for epoch:  6
# EPOCH: 6
# Loss=3.857630729675293 Batch_id=150 Accuracy=16.56: 100%|██████████| 151/151 [01:26<00:00,  1.74it/s]
# Test set: Average loss: 0.0076, Accuracy: 5524/33000 (16.74%)
#
# Validation accuracy increased (14.445455 --> 16.739394).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.024000000000000004  for epoch:  7
# EPOCH: 7
# Loss=3.513577938079834 Batch_id=150 Accuracy=19.38: 100%|██████████| 151/151 [01:30<00:00,  1.67it/s]
# Test set: Average loss: 0.0077, Accuracy: 5723/33000 (17.34%)
#
# Validation accuracy increased (16.739394 --> 17.342424).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.028000000000000004  for epoch:  8
# EPOCH: 8
# Loss=3.4733896255493164 Batch_id=150 Accuracy=21.99: 100%|██████████| 151/151 [01:31<00:00,  1.64it/s]
# Test set: Average loss: 0.0070, Accuracy: 7113/33000 (21.55%)
#
# Validation accuracy increased (17.342424 --> 21.554545).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.032  for epoch:  9
# EPOCH: 9
# Loss=3.1793718338012695 Batch_id=150 Accuracy=23.99: 100%|██████████| 151/151 [01:34<00:00,  1.60it/s]
# Test set: Average loss: 0.0069, Accuracy: 7477/33000 (22.66%)
#
# Validation accuracy increased (21.554545 --> 22.657576).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.036000000000000004  for epoch:  10
# EPOCH: 10
# Loss=3.160942316055298 Batch_id=150 Accuracy=26.22: 100%|██████████| 151/151 [01:35<00:00,  1.58it/s]
# Test set: Average loss: 0.0069, Accuracy: 7640/33000 (23.15%)
#
# Validation accuracy increased (22.657576 --> 23.151515).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.04  for epoch:  11
# EPOCH: 11
# Loss=3.366928815841675 Batch_id=150 Accuracy=28.07: 100%|██████████| 151/151 [01:36<00:00,  1.56it/s]
# Test set: Average loss: 0.0069, Accuracy: 7885/33000 (23.89%)
#
# Validation accuracy increased (23.151515 --> 23.893939).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.044000000000000004  for epoch:  12
# EPOCH: 12
# Loss=2.97615909576416 Batch_id=150 Accuracy=29.82: 100%|██████████| 151/151 [01:35<00:00,  1.59it/s]
# Test set: Average loss: 0.0063, Accuracy: 9199/33000 (27.88%)
#
# Validation accuracy increased (23.893939 --> 27.875758).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.04800000000000001  for epoch:  13
# EPOCH: 13
# Loss=2.9461281299591064 Batch_id=150 Accuracy=31.43: 100%|██████████| 151/151 [01:38<00:00,  1.53it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0065, Accuracy: 8881/33000 (26.91%)
#
# Learning rate = 0.052000000000000005  for epoch:  14
# EPOCH: 14
# Loss=3.029637098312378 Batch_id=150 Accuracy=33.05: 100%|██████████| 151/151 [01:36<00:00,  1.57it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0067, Accuracy: 8609/33000 (26.09%)
#
# Learning rate = 0.05600000000000001  for epoch:  15
# EPOCH: 15
# Loss=2.6512832641601562 Batch_id=150 Accuracy=34.69: 100%|██████████| 151/151 [01:38<00:00,  1.53it/s]
# Test set: Average loss: 0.0063, Accuracy: 9584/33000 (29.04%)
#
# Validation accuracy increased (27.875758 --> 29.042424).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.06  for epoch:  16
# EPOCH: 16
# Loss=2.9957735538482666 Batch_id=150 Accuracy=36.09: 100%|██████████| 151/151 [01:37<00:00,  1.55it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0065, Accuracy: 9313/33000 (28.22%)
#
# Learning rate = 0.064  for epoch:  17
# EPOCH: 17
# Loss=2.604102849960327 Batch_id=150 Accuracy=37.70: 100%|██████████| 151/151 [01:39<00:00,  1.51it/s]
# Test set: Average loss: 0.0060, Accuracy: 10383/33000 (31.46%)
#
# Validation accuracy increased (29.042424 --> 31.463636).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.068  for epoch:  18
# EPOCH: 18
# Loss=2.5704572200775146 Batch_id=150 Accuracy=38.92: 100%|██████████| 151/151 [01:38<00:00,  1.53it/s]
# Test set: Average loss: 0.0060, Accuracy: 10671/33000 (32.34%)
#
# Validation accuracy increased (31.463636 --> 32.336364).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.07200000000000001  for epoch:  19
# EPOCH: 19
# Loss=2.5467476844787598 Batch_id=150 Accuracy=40.75: 100%|██████████| 151/151 [01:37<00:00,  1.56it/s]
# Test set: Average loss: 0.0059, Accuracy: 10880/33000 (32.97%)
#
# Validation accuracy increased (32.336364 --> 32.969697).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.07600000000000001  for epoch:  20
# EPOCH: 20
# Loss=2.630317449569702 Batch_id=150 Accuracy=42.41: 100%|██████████| 151/151 [01:35<00:00,  1.59it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0064, Accuracy: 10048/33000 (30.45%)
#
# Learning rate = 0.08  for epoch:  21
# EPOCH: 21
# Loss=2.2956883907318115 Batch_id=150 Accuracy=43.94: 100%|██████████| 151/151 [01:39<00:00,  1.51it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0063, Accuracy: 10287/33000 (31.17%)
#
# Learning rate = 0.084  for epoch:  22
# EPOCH: 22
# Loss=2.3663055896759033 Batch_id=150 Accuracy=45.50: 100%|██████████| 151/151 [01:40<00:00,  1.51it/s]
# Test set: Average loss: 0.0061, Accuracy: 10918/33000 (33.08%)
#
# Validation accuracy increased (32.969697 --> 33.084848).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.08800000000000001  for epoch:  23
# EPOCH: 23
# Loss=2.3157036304473877 Batch_id=150 Accuracy=46.77: 100%|██████████| 151/151 [01:38<00:00,  1.53it/s]
# Test set: Average loss: 0.0060, Accuracy: 11241/33000 (34.06%)
#
# Validation accuracy increased (33.084848 --> 34.063636).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.09200000000000001  for epoch:  24
# EPOCH: 24
# Loss=2.125140428543091 Batch_id=150 Accuracy=48.76: 100%|██████████| 151/151 [01:34<00:00,  1.60it/s]
# Test set: Average loss: 0.0060, Accuracy: 11293/33000 (34.22%)
#
# Validation accuracy increased (34.063636 --> 34.221212).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# Learning rate = 0.09600000000000002  for epoch:  25
# EPOCH: 25
# Loss=2.298140525817871 Batch_id=150 Accuracy=50.50: 100%|██████████| 151/151 [01:38<00:00,  1.53it/s]
# Test set: Average loss: 0.0062, Accuracy: 11027/33000 (33.42%)
#
# Learning rate = 0.1  for epoch:  26

# %%
train_losses, train_acc = train_model.gettraindata()
test_losses, test_acc = train_model.gettestdata()
utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/learningratefinder.pt",optimizer_state_dict=optimizer.state_dict
                      ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
                      test_losses=test_losses,lr_data=lr_data,class_correct=class_correct,class_total=class_total)

# %%
plotdata.PlotData.plotlrrangetestgraph(lr_data,test_acc,train_acc,test_losses,train_losses)

# %%
import src
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
import src.utils.utils as utils
import src.train.train_model as train
import src.visualization.plotdata as plotdata
import src.preprocessing.preprochelper as preprochelper
from src.utils import cifar_mean,cifar_std
from src.dataset.tinyimagenethelper import TinyImagenetHelper
import torchvision
from src.train.trainhelper import TrainHelper

# %config IPCompleter.greedy=True
# %reload_ext autoreload

# %%
# lr_max = round(0.04935,5)
lr_max = round(0.09,5)
print("lrmax = {}".format(lr_max))
lr_min = round(lr_max / 13,5)
print("lrmin = {}".format(lr_min))
epochs = 50
maxlrepoch = 10
# Out:
# lrmax = 0.04935
# lrmin = 0.0038

# %%
batch_size = 512
helper = TinyImagenetHelper()

path = helper.download_dataset(folder_path="data")
dict = helper.get_id_dictionary(path=path)
values, classes = helper.get_class_to_id_dict(id_dict=dict, path=path)

train_data, train_label, test_data, test_label = helper.get_train_test_labels_data(dict, path)
# calculated mean and std dev values for tiny imagenet takes lot of RAM so not calculating every time
# mean = [0.48043722, 0.44820285, 0.39760238]
# stddev = [0.27698976, 0.26908714, 0.2821603]
# mean, std = utils.Utils.calculate_mean_std_deviation(train_data, test_data)

mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225] 
# batch_size = 64
# compose_train, compose_test = preprochelper.PreprocHelper.getalbumentationstraintesttransforms(mean,std)
train_transforms, test_transforms = preprochelper.PreprocHelper.getpytorchtransforms(mean, std)

ds = dst.Dataset()
# train_dataset = ds.gettraindataset(train_transforms)
# test_dataset = ds.gettestdataset(test_transforms)

train_dataset = ds.get_tiny_imagenet_train_dataset(train_image_data=train_data, train_image_labels=train_label,
                                                   train_transforms=train_transforms)

test_dataset = ds.get_tiny_imagenet_test_dataset(test_image_labels=test_label, test_image_data=test_data,
                                                 test_transforms=test_transforms)

dataloader = dl.Dataloader(traindataset=train_dataset, testdataset=test_dataset, batch_size=batch_size)
train_loader = dataloader.gettraindataloader()
test_loader = dataloader.gettestdataloader()

# specify the image classes
# classes = ds.getclassesinCIFAR10dataset()
data_iterator = iter(train_loader)
plotdata.PlotData.showImagesfromdataset(data_iterator, classes=classes)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 2296.12it/s]
# 10000it [00:00, 834073.22it/s]
# File: tiny-imagenet-200.zip already downloaded.
# File: tiny-imagenet-200 already extracted.
# Starting data loading
# Finished data loading, in 0.10219335556030273 seconds
# CUDA Available? True
# 512
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import torch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

cnn_model = torchvision.models.resnet18(pretrained=False, num_classes=200).cuda(device)
train_model = train.TrainModel()

# %%
from torch.optim.lr_scheduler import LambdaLR
optimizer = utils.Utils.createoptimizer(cnn_model, lr=1, momentum=0.9, weight_decay=0.003, nesterov=True)
lambda1 = TrainHelper.cyclical_lr(maxlrepoch=maxlrepoch, epochs=epochs, minlr=lr_min, maxlr=lr_max)
scheduler = LambdaLR(optimizer, lr_lambda=[lambda1])

# %%
lr_data = []
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

for epoch in range(0, epochs):
    print("EPOCH:", epoch)
    
    for param_groups in optimizer.param_groups:
        print("Learning rate =", param_groups['lr'], " for epoch: ", epoch)  # print LR for different epochs
        lr_data.append(param_groups['lr'])
    
    train_model.train(cnn_model, device, train_loader, optimizer, 1)
    t_acc_epoch = train_model.test(model=cnn_model, device=device, test_loader=test_loader, class_correct=class_correct,
                                   class_total=class_total, epoch=epoch, lr_data=lr_data)
    scheduler.step()
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 0
# Learning rate = 0.0038  for epoch:  0
# Loss=5.098111629486084 Batch_id=150 Accuracy=1.19: 100%|██████████| 151/151 [00:47<00:00,  3.21it/s]
# Test set: Average loss: 0.0100, Accuracy: 903/33000 (2.74%)
#
# Validation accuracy increased (0.000000 --> 2.736364).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 1
# Learning rate = 0.008861111111111111  for epoch:  1
# Loss=4.746957302093506 Batch_id=150 Accuracy=4.18: 100%|██████████| 151/151 [01:31<00:00,  1.66it/s]
# Test set: Average loss: 0.0091, Accuracy: 2167/33000 (6.57%)
#
# Validation accuracy increased (2.736364 --> 6.566667).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 2
# Learning rate = 0.013922222222222221  for epoch:  2
# Loss=4.310469627380371 Batch_id=150 Accuracy=8.53: 100%|██████████| 151/151 [01:36<00:00,  1.56it/s]
# Test set: Average loss: 0.0085, Accuracy: 3306/33000 (10.02%)
#
# Validation accuracy increased (6.566667 --> 10.018182).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 3
# Learning rate = 0.018983333333333335  for epoch:  3
# Loss=3.882916212081909 Batch_id=150 Accuracy=12.83: 100%|██████████| 151/151 [01:35<00:00,  1.58it/s]
# Test set: Average loss: 0.0079, Accuracy: 4587/33000 (13.90%)
#
# Validation accuracy increased (10.018182 --> 13.900000).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 4
# Learning rate = 0.024044444444444445  for epoch:  4
# Loss=3.671602249145508 Batch_id=150 Accuracy=16.75: 100%|██████████| 151/151 [01:38<00:00,  1.54it/s]
# Test set: Average loss: 0.0074, Accuracy: 5819/33000 (17.63%)
#
# Validation accuracy increased (13.900000 --> 17.633333).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 5
# Learning rate = 0.029105555555555555  for epoch:  5
# Loss=3.604205369949341 Batch_id=150 Accuracy=19.51: 100%|██████████| 151/151 [01:39<00:00,  1.52it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0074, Accuracy: 5749/33000 (17.42%)
#
# EPOCH: 6
# Learning rate = 0.034166666666666665  for epoch:  6
# Loss=3.5740599632263184 Batch_id=150 Accuracy=21.75: 100%|██████████| 151/151 [01:42<00:00,  1.48it/s]
# Test set: Average loss: 0.0071, Accuracy: 6608/33000 (20.02%)
#
# Validation accuracy increased (17.633333 --> 20.024242).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 7
# Learning rate = 0.03922777777777777  for epoch:  7
# Loss=3.284942388534546 Batch_id=150 Accuracy=23.52: 100%|██████████| 151/151 [01:39<00:00,  1.51it/s]
# Test set: Average loss: 0.0070, Accuracy: 6832/33000 (20.70%)
#
# Validation accuracy increased (20.024242 --> 20.703030).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 8
# Learning rate = 0.044288888888888885  for epoch:  8
# Loss=3.4051895141601562 Batch_id=150 Accuracy=24.95: 100%|██████████| 151/151 [01:39<00:00,  1.52it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0072, Accuracy: 6503/33000 (19.71%)
#
# EPOCH: 9
# Learning rate = 0.04935  for epoch:  9
# Loss=3.2171356678009033 Batch_id=150 Accuracy=26.11: 100%|██████████| 151/151 [01:38<00:00,  1.53it/s]
# Test set: Average loss: 0.0069, Accuracy: 7154/33000 (21.68%)
#
# Validation accuracy increased (20.703030 --> 21.678788).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 10
# Learning rate = 0.04821125  for epoch:  10
# Loss=3.0234100818634033 Batch_id=150 Accuracy=27.53: 100%|██████████| 151/151 [01:37<00:00,  1.55it/s]
# Test set: Average loss: 0.0068, Accuracy: 7544/33000 (22.86%)
#
# Validation accuracy increased (21.678788 --> 22.860606).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 11
# Learning rate = 0.047072499999999996  for epoch:  11
# Loss=3.1331183910369873 Batch_id=150 Accuracy=28.93: 100%|██████████| 151/151 [01:33<00:00,  1.61it/s]
# Test set: Average loss: 0.0064, Accuracy: 8840/33000 (26.79%)
#
# Validation accuracy increased (22.860606 --> 26.787879).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 12
# Learning rate = 0.045933749999999995  for epoch:  12
# Loss=2.9422829151153564 Batch_id=150 Accuracy=30.08: 100%|██████████| 151/151 [01:34<00:00,  1.61it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0065, Accuracy: 8384/33000 (25.41%)
#
# EPOCH: 13
# Learning rate = 0.044795  for epoch:  13
# Loss=3.183267831802368 Batch_id=150 Accuracy=31.12: 100%|██████████| 151/151 [01:38<00:00,  1.53it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0064, Accuracy: 8573/33000 (25.98%)
#
# EPOCH: 14
# Learning rate = 0.04365625  for epoch:  14
# Loss=2.893092155456543 Batch_id=150 Accuracy=32.02: 100%|██████████| 151/151 [01:35<00:00,  1.58it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0074, Accuracy: 6682/33000 (20.25%)
#
# EPOCH: 15
# Learning rate = 0.0425175  for epoch:  15
# Loss=2.9496288299560547 Batch_id=150 Accuracy=33.00: 100%|██████████| 151/151 [01:35<00:00,  1.58it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0067, Accuracy: 7845/33000 (23.77%)
#
# EPOCH: 16
# Learning rate = 0.04137875  for epoch:  16
# Loss=2.7129244804382324 Batch_id=150 Accuracy=33.82: 100%|██████████| 151/151 [01:36<00:00,  1.57it/s]
# Test set: Average loss: 0.0063, Accuracy: 8989/33000 (27.24%)
#
# Validation accuracy increased (26.787879 --> 27.239394).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 17
# Learning rate = 0.04024  for epoch:  17
# Loss=2.99385929107666 Batch_id=150 Accuracy=34.68: 100%|██████████| 151/151 [01:31<00:00,  1.65it/s]
# Test set: Average loss: 0.0061, Accuracy: 9682/33000 (29.34%)
#
# Validation accuracy increased (27.239394 --> 29.339394).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 18
# Learning rate = 0.03910125  for epoch:  18
# Loss=2.6675708293914795 Batch_id=150 Accuracy=35.67: 100%|██████████| 151/151 [01:35<00:00,  1.58it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0062, Accuracy: 9359/33000 (28.36%)
#
# EPOCH: 19
# Learning rate = 0.037962499999999996  for epoch:  19
# Loss=2.5903868675231934 Batch_id=150 Accuracy=36.33: 100%|██████████| 151/151 [01:35<00:00,  1.58it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0063, Accuracy: 9176/33000 (27.81%)
#
# EPOCH: 20
# Learning rate = 0.03682375  for epoch:  20
# Loss=2.7621066570281982 Batch_id=150 Accuracy=37.60: 100%|██████████| 151/151 [01:36<00:00,  1.57it/s]
# Test set: Average loss: 0.0060, Accuracy: 10029/33000 (30.39%)
#
# Validation accuracy increased (29.339394 --> 30.390909).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 21
# Learning rate = 0.035684999999999995  for epoch:  21
# Loss=2.734084367752075 Batch_id=150 Accuracy=38.18: 100%|██████████| 151/151 [01:31<00:00,  1.64it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0061, Accuracy: 9904/33000 (30.01%)
#
# EPOCH: 22
# Learning rate = 0.03454625  for epoch:  22
# Loss=2.630869150161743 Batch_id=150 Accuracy=38.65: 100%|██████████| 151/151 [01:33<00:00,  1.62it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0060, Accuracy: 9917/33000 (30.05%)
#
# EPOCH: 23
# Learning rate = 0.0334075  for epoch:  23
# Loss=2.5953543186187744 Batch_id=150 Accuracy=39.47: 100%|██████████| 151/151 [01:33<00:00,  1.62it/s]
# Test set: Average loss: 0.0059, Accuracy: 10674/33000 (32.35%)
#
# Validation accuracy increased (30.390909 --> 32.345455).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 24
# Learning rate = 0.03226875  for epoch:  24
# Loss=2.4836838245391846 Batch_id=150 Accuracy=40.35: 100%|██████████| 151/151 [01:32<00:00,  1.64it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0059, Accuracy: 10544/33000 (31.95%)
#
# EPOCH: 25
# Learning rate = 0.031129999999999998  for epoch:  25
# Loss=2.342648506164551 Batch_id=150 Accuracy=41.06: 100%|██████████| 151/151 [01:36<00:00,  1.56it/s]
# Test set: Average loss: 0.0055, Accuracy: 11496/33000 (34.84%)
#
# Validation accuracy increased (32.345455 --> 34.836364).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 26
# Learning rate = 0.029991249999999997  for epoch:  26
# Loss=2.566523551940918 Batch_id=150 Accuracy=41.99: 100%|██████████| 151/151 [01:33<00:00,  1.61it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0059, Accuracy: 10608/33000 (32.15%)
#
# EPOCH: 27
# Learning rate = 0.028852499999999996  for epoch:  27
# Loss=2.5070948600769043 Batch_id=150 Accuracy=42.51: 100%|██████████| 151/151 [01:32<00:00,  1.63it/s]
# Test set: Average loss: 0.0055, Accuracy: 11671/33000 (35.37%)
#
# Validation accuracy increased (34.836364 --> 35.366667).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 28
# Learning rate = 0.02771375  for epoch:  28
# Loss=2.393866539001465 Batch_id=150 Accuracy=43.37: 100%|██████████| 151/151 [01:33<00:00,  1.62it/s]
# Test set: Average loss: 0.0054, Accuracy: 11858/33000 (35.93%)
#
# Validation accuracy increased (35.366667 --> 35.933333).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 29
# Learning rate = 0.026574999999999998  for epoch:  29
# Loss=2.351163387298584 Batch_id=150 Accuracy=44.05: 100%|██████████| 151/151 [01:28<00:00,  1.70it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0054, Accuracy: 11797/33000 (35.75%)
#
# EPOCH: 30
# Learning rate = 0.025436249999999997  for epoch:  30
# Loss=2.4065041542053223 Batch_id=150 Accuracy=44.80: 100%|██████████| 151/151 [01:31<00:00,  1.64it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0056, Accuracy: 11282/33000 (34.19%)
#
# EPOCH: 31
# Learning rate = 0.0242975  for epoch:  31
# Loss=2.176450252532959 Batch_id=150 Accuracy=45.59: 100%|██████████| 151/151 [01:34<00:00,  1.60it/s]
# Test set: Average loss: 0.0054, Accuracy: 12047/33000 (36.51%)
#
# Validation accuracy increased (35.933333 --> 36.506061).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 32
# Learning rate = 0.02315875  for epoch:  32
# Loss=2.296769142150879 Batch_id=150 Accuracy=46.57: 100%|██████████| 151/151 [01:28<00:00,  1.70it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0054, Accuracy: 12018/33000 (36.42%)
#
# EPOCH: 33
# Learning rate = 0.022019999999999998  for epoch:  33
# Loss=2.2480123043060303 Batch_id=150 Accuracy=47.13: 100%|██████████| 151/151 [01:31<00:00,  1.65it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0055, Accuracy: 11745/33000 (35.59%)
#
# EPOCH: 34
# Learning rate = 0.020881249999999997  for epoch:  34
# Loss=2.289863348007202 Batch_id=150 Accuracy=48.09: 100%|██████████| 151/151 [01:31<00:00,  1.64it/s]
# Test set: Average loss: 0.0054, Accuracy: 12265/33000 (37.17%)
#
# Validation accuracy increased (36.506061 --> 37.166667).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 35
# Learning rate = 0.019742499999999996  for epoch:  35
# Loss=2.2602734565734863 Batch_id=150 Accuracy=49.18: 100%|██████████| 151/151 [01:25<00:00,  1.77it/s]
# Test set: Average loss: 0.0052, Accuracy: 12832/33000 (38.88%)
#
# Validation accuracy increased (37.166667 --> 38.884848).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 36
# Learning rate = 0.01860375  for epoch:  36
# Loss=2.123645544052124 Batch_id=150 Accuracy=50.23: 100%|██████████| 151/151 [01:21<00:00,  1.85it/s]
# Test set: Average loss: 0.0051, Accuracy: 12981/33000 (39.34%)
#
# Validation accuracy increased (38.884848 --> 39.336364).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 37
# Learning rate = 0.017465  for epoch:  37
# Loss=2.245002508163452 Batch_id=150 Accuracy=51.12: 100%|██████████| 151/151 [01:21<00:00,  1.86it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0052, Accuracy: 12817/33000 (38.84%)
#
# EPOCH: 38
# Learning rate = 0.01632625  for epoch:  38
# Loss=2.0696308612823486 Batch_id=150 Accuracy=52.11: 100%|██████████| 151/151 [01:21<00:00,  1.86it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 12667/33000 (38.38%)
#
# EPOCH: 39
# Learning rate = 0.0151875  for epoch:  39
# Loss=1.9888203144073486 Batch_id=150 Accuracy=53.37: 100%|██████████| 151/151 [01:20<00:00,  1.87it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 12728/33000 (38.57%)
#
# EPOCH: 40
# Learning rate = 0.014048749999999999  for epoch:  40
# Loss=2.0085372924804688 Batch_id=150 Accuracy=54.41: 100%|██████████| 151/151 [01:36<00:00,  1.56it/s]
# Test set: Average loss: 0.0051, Accuracy: 13360/33000 (40.48%)
#
# Validation accuracy increased (39.336364 --> 40.484848).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 41
# Learning rate = 0.012909999999999998  for epoch:  41
# Loss=1.9147000312805176 Batch_id=150 Accuracy=56.05: 100%|██████████| 151/151 [01:30<00:00,  1.66it/s]
# Test set: Average loss: 0.0049, Accuracy: 13996/33000 (42.41%)
#
# Validation accuracy increased (40.484848 --> 42.412121).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 42
# Learning rate = 0.011771249999999997  for epoch:  42
# Loss=1.7945098876953125 Batch_id=150 Accuracy=57.34: 100%|██████████| 151/151 [01:30<00:00,  1.66it/s]
# Test set: Average loss: 0.0048, Accuracy: 14068/33000 (42.63%)
#
# Validation accuracy increased (42.412121 --> 42.630303).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 43
# Learning rate = 0.010632499999999996  for epoch:  43
# Loss=1.908647894859314 Batch_id=150 Accuracy=58.57: 100%|██████████| 151/151 [01:30<00:00,  1.66it/s]
# Test set: Average loss: 0.0048, Accuracy: 14292/33000 (43.31%)
#
# Validation accuracy increased (42.630303 --> 43.309091).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 44
# Learning rate = 0.009493749999999995  for epoch:  44
# Loss=1.8361940383911133 Batch_id=150 Accuracy=60.48: 100%|██████████| 151/151 [01:36<00:00,  1.56it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0048, Accuracy: 14193/33000 (43.01%)
#
# EPOCH: 45
# Learning rate = 0.008354999999999994  for epoch:  45
# Loss=1.6213852167129517 Batch_id=150 Accuracy=62.51: 100%|██████████| 151/151 [01:36<00:00,  1.56it/s]
# Test set: Average loss: 0.0048, Accuracy: 14455/33000 (43.80%)
#
# Validation accuracy increased (43.309091 --> 43.803030).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 46
# Learning rate = 0.0072162500000000004  for epoch:  46
# Loss=1.4369416236877441 Batch_id=150 Accuracy=64.57: 100%|██████████| 151/151 [01:33<00:00,  1.62it/s]
# Test set: Average loss: 0.0047, Accuracy: 14899/33000 (45.15%)
#
# Validation accuracy increased (43.803030 --> 45.148485).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 47
# Learning rate = 0.0060775  for epoch:  47
# Loss=1.529550313949585 Batch_id=150 Accuracy=67.12: 100%|██████████| 151/151 [01:31<00:00,  1.66it/s]
# Test set: Average loss: 0.0045, Accuracy: 15157/33000 (45.93%)
#
# Validation accuracy increased (45.148485 --> 45.930303).  Saving model ...
#   0%|          | 0/151 [00:00<?, ?it/s]
# EPOCH: 48
# Learning rate = 0.004938749999999999  for epoch:  48
# Loss=1.5376237630844116 Batch_id=150 Accuracy=69.53: 100%|██████████| 151/151 [01:32<00:00,  1.63it/s]
#   0%|          | 0/151 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 15044/33000 (45.59%)
#
# EPOCH: 49
# Learning rate = 0.003799999999999998  for epoch:  49
# Loss=1.1835356950759888 Batch_id=150 Accuracy=72.45: 100%|██████████| 151/151 [01:31<00:00,  1.65it/s]
# Test set: Average loss: 0.0045, Accuracy: 15327/33000 (46.45%)
#
# Validation accuracy increased (45.930303 --> 46.445455).  Saving model ...

# %%
train_losses, train_acc = train_model.gettraindata()
test_losses, test_acc = train_model.gettestdata()
utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/finalmodelwithdata.pt",optimizer_state_dict=optimizer.state_dict
                      ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
                      test_losses=test_losses,lr_data=lr_data,class_correct=class_correct,class_total=class_total)

# %%
plotdata.PlotData.plottesttraingraph(train_losses=train_losses,train_acc=train_acc,test_losses=test_losses,
                                     test_acc=test_acc,lr_data=lr_data, plotonsamegraph=True,epochs=epoch,doProcessArray=False)

# %%
# plotdata.PlotData.plotlrrangetestgraph(lr_data,test_acc,train_acc,test_losses,train_losses)

# %%
import torch
import src.utils.utils as utils
import src.preprocessing.albumentationstransforms as preprocessing
preproc = preprocessing.AlbumentaionsTransforms()
import src.preprocessing.preprochelper as preprochelper
import glob
from PIL import Image
from src.utils.modelutils import *
import src.visualization.plotdata as plotdata
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
import src.preprocessing.customcompose as customcompose
import src.train.train_model as train
import torch
from torch.utils.tensorboard import SummaryWriter
import torchvision
from src.visualization.tensorboard.tensorboardhelper import TensorboardHelper

# %load_ext tensorboard

# %%
print(torch.cuda.is_available())
saved_data, epoch, model_state_dict, optimizer_state_dict, train_losses, train_acc, test_losses, test_acc\
            , test_losses, lr_data, class_correct, class_total\
= utils.Utils.loadmodel(path="savedmodels/finalmodelwithdata.pt")
# Out:
# True

# %%
model, device = utils.Utils.createA11CustomResnetModel(model_state_dict=model_state_dict)
# Out:
# cuda

# %%
train_transforms, test_transforms = preprochelper.PreprocHelper.getpytorchtransforms((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
ds = dst.Dataset()
train_dataset = ds.gettraindataset(train_transforms)
test_dataset = ds.gettestdataset(test_transforms)

batch_size = 512
dataloader = dl.Cifar10Dataloader(traindataset=train_dataset, testdataset=test_dataset,batch_size=batch_size)
test_loader = dataloader.gettestdataloader()
train_loader = dataloader.gettraindataloader()

# obtain one batch of test images
dataiterator = iter(test_loader)
# specify the image classes
classes = ds.getclassesinCIFAR10dataset()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CUDA Available? True
# 512

# %%
classified, misclassified = train.TrainModel.getinferredimagesfromdataset(dataiterator=dataiterator, model=model,
                                                                          classes=classes, batch_size=batch_size,
                                                                          number=2)

# %%
plotdata.PlotData.plotinferredimagesfromdataset(misclassified, model, device, classes,"misclassifed"
                                                ,size=(15,20),layerNo=20)

# %%
plotdata.PlotData.plotinferredimagesfromdataset(classified, model, device, classes,"correct"
                                                ,size=(15,20),layerNo=20)

# %%
# from src.utils.modelutils import subplot
image_paths = glob.glob('./images/testimages/*.*')
images = list(map(lambda x: Image.open(x), image_paths))
subplot(images, title='inputs', nrows=2, ncols=5)

# %%
inputs = [torchvision.transforms.Compose([torchvision.transforms.Resize((32, 32)), torchvision.transforms.ToTensor(),
                                          torchvision.transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])(
    x).unsqueeze(0) for x in images]  # add 1 dim for batch
inputs = [i.to(device) for i in inputs]

# %%
from src.visualization.gradcam.gradcam import GradCam
from src.visualization.gradcam import gradcamhelper

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']


# print("Gradcam of external images for Layer 34, Conv2d, Output Shape = 8")
loc = 0
for input in inputs:  
    dict = {loc:input}
    plotdata.PlotData.plotinferredimagesfromdataset(dict, model, device, classes,"external"
                                                ,size=(15,20),layerNo=20)
    loc += 1

# %%
images, labels = next(iter(train_loader))

# %%
# model, device = utils.Utils.createmodelresnet18(model_state_dict=model_state_dict)
images, labels = images.to(device), labels.to(device)
grid = torchvision.utils.make_grid(images)

# %%
epochs = epoch

# %%
writer = SummaryWriter("customresnet_onecycle_A11")
writer.add_image('images', grid, 0)
writer.add_graph(model, images)

# %%
print(epochs)
for epoch in range(0, epochs):
    writer.add_scalars('Loss', {'Train': train_losses[epoch],'Test': test_losses[epoch],}, epoch+1)
    writer.add_scalars('Accuracy', {'Train': train_acc[epoch],'Test': test_acc[epoch],}, epoch+1)
    writer.add_scalar('LR', lr_data[epoch], epoch+1)
    writer.add_histogram('Test Accuracy distribution', test_acc[epoch], epoch+1)
    writer.add_histogram('Test Loss distribution', test_losses[epoch], epoch+1)
    writer.add_histogram('Train Accuracy distribution', train_acc[epoch], epoch+1)
    writer.add_histogram('Train Loss distribution', train_losses[epoch], epoch+1)
    
writer.close()
# Out:
# 24

# %%
tensorboard --logdir=customresnet_onecycle_A11
# Out:
#       <iframe id="tensorboard-frame-52fed36f54f452e6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-52fed36f54f452e6");
#           const url = new URL("/", window.location);
#           url.port = 6009;
#           frame.src = url;
#         })();
#       </script>

# %%
# torch.cuda.empty_cache()

# test_dataset = None
# train_dataset = None
# test_loader = None
# train_loader = None

# import gc
# gc.collect()
# Out:
# 43061

# %%
# !kill 27460
