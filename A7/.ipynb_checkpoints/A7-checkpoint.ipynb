# %% [markdown]
# # Import Libraries

# %%
import datetime
print("Model execution started at:" + datetime.datetime.today().ctime())
# Out:
# Model execution started at:Sat Mar  7 17:10:53 2020

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sat Mar  7 17:10:53 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.59       Driver Version: 440.59       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1070    Off  | 00000000:01:00.0  On |                  N/A |
# | N/A   76C    P0    38W /  N/A |    838MiB /  8117MiB |      4%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      1715      G   /usr/lib/xorg/Xorg                            18MiB |
# |    0      1772      G   /usr/bin/gnome-shell                          48MiB |
# |    0      2094      G   /usr/lib/xorg/Xorg                           284MiB |
# |    0      2248      G   /usr/bin/gnome-shell                         233MiB |
# |    0      3745      G   ...AAAAAAAAAAAAAAgAAAAAAAAA --shared-files   155MiB |
# |    0      7949      G   ...p/pycharm-professional/183/jbr/bin/java    39MiB |
# |    0     21855      G   ...equest-channel-token=321728551168512436    52MiB |
# +-----------------------------------------------------------------------------+

# %%
# from psutil import virtual_memory
# ram_gb = virtual_memory().total / 1e9
# print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

# if ram_gb < 20:
#   print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
#   print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
#   print('re-execute this cell.')
# else:
#   print('You are using a high-RAM runtime!')

# %%
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
import src.preprocessing.preprocessing as preprocessing
# import matplotlib.pyplot as plt
# import numpy as np
import src.utils.utils as utils
import src.models.train_model as train
# %matplotlib inline
import src.visualization.plotdata as plotdata

# %config IPCompleter.greedy=True

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
preproc = preprocessing.Preprocessing()

train_transforms = preproc.gettraintransforms()
test_transforms = preproc.gettesttransforms()

# %%
ds = dst.Dataset()
train_dataset = ds.gettraindataset(train_transforms)
test_dataset = ds.gettestdataset(test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 128
dataloader = dl.Cifar10Dataloader(traindataset=train_dataset, testdataset=test_dataset,batch_size=batch_size)

train_loader = dataloader.gettraindataloader()
test_loader = dataloader.gettestdataloader()
# Out:
# CUDA Available? True
# 128

# %%
# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

# obtain one batch of training images
dataiterator = iter(train_loader)
images, labels = dataiterator.next()
images = images.numpy()  # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20 / 2, idx + 1, xticks=[], yticks=[])
    utils.Utils.imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %%
cnn_model, device = utils.Utils.createmodel()
train_model = train.TrainModel()
train_model.showmodelsummary(cnn_model)
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#            Dropout-4           [-1, 32, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]             288
#             Conv2d-6           [-1, 32, 32, 32]           1,056
# DepthwiseSeparableConv2d-7           [-1, 32, 32, 32]               0
#        BatchNorm2d-8           [-1, 32, 32, 32]              64
#               ReLU-9           [-1, 32, 32, 32]               0
#           Dropout-10           [-1, 32, 32, 32]               0
#            Conv2d-11           [-1, 64, 30, 30]          18,432
#       BatchNorm2d-12           [-1, 64, 30, 30]             128
#              ReLU-13           [-1, 64, 30, 30]               0
#           Dropout-14           [-1, 64, 30, 30]               0
#         MaxPool2d-15           [-1, 64, 15, 15]               0
#            Conv2d-16           [-1, 32, 15, 15]          18,432
#       BatchNorm2d-17           [-1, 32, 15, 15]              64
#              ReLU-18           [-1, 32, 15, 15]               0
#           Dropout-19           [-1, 32, 15, 15]               0
#            Conv2d-20           [-1, 32, 15, 15]             288
#            Conv2d-21           [-1, 32, 15, 15]           1,056
# DepthwiseSeparableConv2d-22           [-1, 32, 15, 15]               0
#       BatchNorm2d-23           [-1, 32, 15, 15]              64
#              ReLU-24           [-1, 32, 15, 15]               0
#           Dropout-25           [-1, 32, 15, 15]               0
#            Conv2d-26           [-1, 64, 13, 13]          18,432
#       BatchNorm2d-27           [-1, 64, 13, 13]             128
#              ReLU-28           [-1, 64, 13, 13]               0
#           Dropout-29           [-1, 64, 13, 13]               0
#         MaxPool2d-30             [-1, 64, 6, 6]               0
#            Conv2d-31             [-1, 32, 6, 6]          18,432
#       BatchNorm2d-32             [-1, 32, 6, 6]              64
#              ReLU-33             [-1, 32, 6, 6]               0
#           Dropout-34             [-1, 32, 6, 6]               0
#            Conv2d-35             [-1, 32, 6, 6]             288
#            Conv2d-36             [-1, 32, 6, 6]           1,056
# DepthwiseSeparableConv2d-37             [-1, 32, 6, 6]               0
#       BatchNorm2d-38             [-1, 32, 6, 6]              64
#              ReLU-39             [-1, 32, 6, 6]               0
#           Dropout-40             [-1, 32, 6, 6]               0
#            Conv2d-41             [-1, 64, 2, 2]          18,432
#       BatchNorm2d-42             [-1, 64, 2, 2]             128
#              ReLU-43             [-1, 64, 2, 2]               0
#           Dropout-44             [-1, 64, 2, 2]               0
#         AvgPool2d-45             [-1, 64, 1, 1]               0
#            Linear-46                   [-1, 10]             640
# ================================================================
# Total params: 98,464
# Trainable params: 98,464
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.36
# Params size (MB): 0.38
# Estimated Total Size (MB): 5.75
# ----------------------------------------------------------------

# %%
optimizer = utils.Utils.createoptimizer(cnn_model, lr=0.1, momentum=0.9, weight_decay=0)
scheduler = utils.Utils.createscheduler(optimizer, mode='max', factor=0.1, patience=2,
                                        verbose=True)

# %%
lr_data = []
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
epochs = 51
for epoch in range(1, epochs):
    print("EPOCH:", epoch)
    train_model.train(cnn_model, device, train_loader, optimizer, 1)
    t_acc_epoch = train_model.test(cnn_model, device, test_loader, class_correct=class_correct,
                                   class_total=class_total, epoch=epoch)
    scheduler.step(t_acc_epoch)
    for param_groups in optimizer.param_groups:
        print("Learning rate =", param_groups['lr'], " for epoch: ", epoch + 1)  # print LR for different epochs
        lr_data.append(param_groups['lr'])
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 1
# /home/abhijit/.virtualenvs/dl4cv/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=1.171053409576416 Batch_id=390 Accuracy=46.29: 100%|██████████| 391/391 [00:28<00:00, 13.78it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0102, Accuracy: 5313/10000 (53.13%)
#
# Validation accuracy increased (0.000000 --> 53.130000).  Saving model ...
# Learning rate = 0.1  for epoch:  2
# EPOCH: 2
# Loss=1.175905466079712 Batch_id=390 Accuracy=60.55: 100%|██████████| 391/391 [00:29<00:00, 13.32it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0083, Accuracy: 6249/10000 (62.49%)
#
# Validation accuracy increased (53.130000 --> 62.490000).  Saving model ...
# Learning rate = 0.1  for epoch:  3
# EPOCH: 3
# Loss=0.9021438360214233 Batch_id=390 Accuracy=66.36: 100%|██████████| 391/391 [00:32<00:00, 12.19it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0079, Accuracy: 6449/10000 (64.49%)
#
# Validation accuracy increased (62.490000 --> 64.490000).  Saving model ...
# Learning rate = 0.1  for epoch:  4
# EPOCH: 4
# Loss=0.8827993273735046 Batch_id=390 Accuracy=69.89: 100%|██████████| 391/391 [00:32<00:00, 11.87it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0075, Accuracy: 6640/10000 (66.40%)
#
# Validation accuracy increased (64.490000 --> 66.400000).  Saving model ...
# Learning rate = 0.1  for epoch:  5
# EPOCH: 5
# Loss=0.81951904296875 Batch_id=390 Accuracy=72.04: 100%|██████████| 391/391 [00:33<00:00, 11.73it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0063, Accuracy: 7214/10000 (72.14%)
#
# Validation accuracy increased (66.400000 --> 72.140000).  Saving model ...
# Learning rate = 0.1  for epoch:  6
# EPOCH: 6
# Loss=0.8822706341743469 Batch_id=390 Accuracy=73.75: 100%|██████████| 391/391 [00:32<00:00, 12.14it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0059, Accuracy: 7400/10000 (74.00%)
#
# Validation accuracy increased (72.140000 --> 74.000000).  Saving model ...
# Learning rate = 0.1  for epoch:  7
# EPOCH: 7
# Loss=0.6599966883659363 Batch_id=390 Accuracy=75.15: 100%|██████████| 391/391 [00:32<00:00, 11.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0065, Accuracy: 7083/10000 (70.83%)
#
# Learning rate = 0.1  for epoch:  8
# EPOCH: 8
# Loss=0.5583283305168152 Batch_id=390 Accuracy=75.91: 100%|██████████| 391/391 [00:33<00:00, 11.69it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0063, Accuracy: 7289/10000 (72.89%)
#
# Validation accuracy increased (70.830000 --> 72.890000).  Saving model ...
# Learning rate = 0.1  for epoch:  9
# EPOCH: 9
# Loss=0.5919986963272095 Batch_id=390 Accuracy=76.87: 100%|██████████| 391/391 [00:34<00:00, 11.39it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 7669/10000 (76.69%)
#
# Validation accuracy increased (72.890000 --> 76.690000).  Saving model ...
# Learning rate = 0.1  for epoch:  10
# EPOCH: 10
# Loss=0.6362920999526978 Batch_id=390 Accuracy=77.79: 100%|██████████| 391/391 [00:33<00:00, 11.54it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0055, Accuracy: 7611/10000 (76.11%)
#
# Learning rate = 0.1  for epoch:  11
# EPOCH: 11
# Loss=0.5606886148452759 Batch_id=390 Accuracy=78.47: 100%|██████████| 391/391 [00:33<00:00, 11.73it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 7736/10000 (77.36%)
#
# Validation accuracy increased (76.110000 --> 77.360000).  Saving model ...
# Learning rate = 0.1  for epoch:  12
# EPOCH: 12
# Loss=0.7411778569221497 Batch_id=390 Accuracy=78.70: 100%|██████████| 391/391 [00:32<00:00, 12.11it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0052, Accuracy: 7712/10000 (77.12%)
#
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Learning rate = 0.010000000000000002  for epoch:  13
# EPOCH: 13
# Loss=0.7037572264671326 Batch_id=390 Accuracy=81.32: 100%|██████████| 391/391 [00:32<00:00, 11.93it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8041/10000 (80.41%)
#
# Validation accuracy increased (77.120000 --> 80.410000).  Saving model ...
# Learning rate = 0.010000000000000002  for epoch:  14
# EPOCH: 14
# Loss=0.48360806703567505 Batch_id=390 Accuracy=81.95: 100%|██████████| 391/391 [00:34<00:00, 11.20it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8052/10000 (80.52%)
#
# Validation accuracy increased (80.410000 --> 80.520000).  Saving model ...
# Learning rate = 0.010000000000000002  for epoch:  15
# EPOCH: 15
# Loss=0.5009691119194031 Batch_id=390 Accuracy=82.66: 100%|██████████| 391/391 [00:34<00:00, 11.28it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8014/10000 (80.14%)
#
# Learning rate = 0.010000000000000002  for epoch:  16
# EPOCH: 16
# Loss=0.6324712634086609 Batch_id=390 Accuracy=82.50: 100%|██████████| 391/391 [00:35<00:00, 11.15it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8064/10000 (80.64%)
#
# Validation accuracy increased (80.140000 --> 80.640000).  Saving model ...
# Epoch    16: reducing learning rate of group 0 to 1.0000e-03.
# Learning rate = 0.0010000000000000002  for epoch:  17
# EPOCH: 17
# Loss=0.6317464113235474 Batch_id=390 Accuracy=82.87: 100%|██████████| 391/391 [00:34<00:00, 11.44it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8083/10000 (80.83%)
#
# Validation accuracy increased (80.640000 --> 80.830000).  Saving model ...
# Learning rate = 0.0010000000000000002  for epoch:  18
# EPOCH: 18
# Loss=0.4550427496433258 Batch_id=390 Accuracy=83.06: 100%|██████████| 391/391 [00:34<00:00, 11.33it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8051/10000 (80.51%)
#
# Learning rate = 0.0010000000000000002  for epoch:  19
# EPOCH: 19
# Loss=0.43052148818969727 Batch_id=390 Accuracy=82.84: 100%|██████████| 391/391 [00:34<00:00, 11.50it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8059/10000 (80.59%)
#
# Validation accuracy increased (80.510000 --> 80.590000).  Saving model ...
# Epoch    19: reducing learning rate of group 0 to 1.0000e-04.
# Learning rate = 0.00010000000000000003  for epoch:  20
# EPOCH: 20
# Loss=0.45187264680862427 Batch_id=390 Accuracy=83.07: 100%|██████████| 391/391 [00:33<00:00, 11.53it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8067/10000 (80.67%)
#
# Validation accuracy increased (80.590000 --> 80.670000).  Saving model ...
# Learning rate = 0.00010000000000000003  for epoch:  21
# EPOCH: 21
# Loss=0.5374348163604736 Batch_id=390 Accuracy=82.96: 100%|██████████| 391/391 [00:34<00:00, 11.23it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8068/10000 (80.68%)
#
# Validation accuracy increased (80.670000 --> 80.680000).  Saving model ...
# Learning rate = 0.00010000000000000003  for epoch:  22
# EPOCH: 22
# Loss=0.35895970463752747 Batch_id=390 Accuracy=82.90: 100%|██████████| 391/391 [00:34<00:00, 11.44it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8063/10000 (80.63%)
#
# Epoch    22: reducing learning rate of group 0 to 1.0000e-05.
# Learning rate = 1.0000000000000004e-05  for epoch:  23
# EPOCH: 23
# Loss=0.685113787651062 Batch_id=390 Accuracy=82.97: 100%|██████████| 391/391 [00:34<00:00, 11.35it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8046/10000 (80.46%)
#
# Learning rate = 1.0000000000000004e-05  for epoch:  24
# EPOCH: 24
# Loss=0.35570698976516724 Batch_id=390 Accuracy=82.96: 100%|██████████| 391/391 [00:32<00:00, 11.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8077/10000 (80.77%)
#
# Validation accuracy increased (80.460000 --> 80.770000).  Saving model ...
# Learning rate = 1.0000000000000004e-05  for epoch:  25
# EPOCH: 25
# Loss=0.45612555742263794 Batch_id=390 Accuracy=83.00: 100%|██████████| 391/391 [00:33<00:00, 11.55it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8068/10000 (80.68%)
#
# Epoch    25: reducing learning rate of group 0 to 1.0000e-06.
# Learning rate = 1.0000000000000004e-06  for epoch:  26
# EPOCH: 26
# Loss=0.41992616653442383 Batch_id=390 Accuracy=82.91: 100%|██████████| 391/391 [00:33<00:00, 11.51it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8068/10000 (80.68%)
#
# Validation accuracy increased (80.680000 --> 80.680000).  Saving model ...
# Learning rate = 1.0000000000000004e-06  for epoch:  27
# EPOCH: 27
# Loss=0.5103827714920044 Batch_id=390 Accuracy=82.94: 100%|██████████| 391/391 [00:33<00:00, 11.60it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8060/10000 (80.60%)
#
# Learning rate = 1.0000000000000004e-06  for epoch:  28
# EPOCH: 28
# Loss=0.519220232963562 Batch_id=390 Accuracy=82.95: 100%|██████████| 391/391 [00:34<00:00, 11.39it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8084/10000 (80.84%)
#
# Validation accuracy increased (80.600000 --> 80.840000).  Saving model ...
# Epoch    28: reducing learning rate of group 0 to 1.0000e-07.
# Learning rate = 1.0000000000000005e-07  for epoch:  29
# EPOCH: 29
# Loss=0.5846375226974487 Batch_id=390 Accuracy=82.97: 100%|██████████| 391/391 [00:34<00:00, 11.35it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8103/10000 (81.03%)
#
# Validation accuracy increased (80.840000 --> 81.030000).  Saving model ...
# Learning rate = 1.0000000000000005e-07  for epoch:  30
# EPOCH: 30
# Loss=0.5453049540519714 Batch_id=390 Accuracy=83.07: 100%|██████████| 391/391 [00:32<00:00, 12.05it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8064/10000 (80.64%)
#
# Learning rate = 1.0000000000000005e-07  for epoch:  31
# EPOCH: 31
# Loss=0.5847519636154175 Batch_id=390 Accuracy=83.07: 100%|██████████| 391/391 [00:33<00:00, 11.71it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8051/10000 (80.51%)
#
# Epoch    31: reducing learning rate of group 0 to 1.0000e-08.
# Learning rate = 1.0000000000000005e-08  for epoch:  32
# EPOCH: 32
# Loss=0.44083505868911743 Batch_id=390 Accuracy=82.99: 100%|██████████| 391/391 [00:33<00:00, 11.76it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8076/10000 (80.76%)
#
# Validation accuracy increased (80.510000 --> 80.760000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  33
# EPOCH: 33
# Loss=0.4400065839290619 Batch_id=390 Accuracy=82.93: 100%|██████████| 391/391 [00:33<00:00, 11.71it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8054/10000 (80.54%)
#
# Learning rate = 1.0000000000000005e-08  for epoch:  34
# EPOCH: 34
# Loss=0.5252972841262817 Batch_id=390 Accuracy=82.91: 100%|██████████| 391/391 [00:32<00:00, 11.90it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8071/10000 (80.71%)
#
# Validation accuracy increased (80.540000 --> 80.710000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  35
# EPOCH: 35
# Loss=0.42950814962387085 Batch_id=390 Accuracy=82.98: 100%|██████████| 391/391 [00:33<00:00, 11.61it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8044/10000 (80.44%)
#
# Learning rate = 1.0000000000000005e-08  for epoch:  36
# EPOCH: 36
# Loss=0.4367522597312927 Batch_id=390 Accuracy=83.05: 100%|██████████| 391/391 [00:34<00:00, 11.46it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8048/10000 (80.48%)
#
# Validation accuracy increased (80.440000 --> 80.480000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  37
# EPOCH: 37
# Loss=0.4125491678714752 Batch_id=390 Accuracy=83.17: 100%|██████████| 391/391 [00:35<00:00, 11.12it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8091/10000 (80.91%)
#
# Validation accuracy increased (80.480000 --> 80.910000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  38
# EPOCH: 38
# Loss=0.5205153822898865 Batch_id=390 Accuracy=83.07: 100%|██████████| 391/391 [00:34<00:00, 11.22it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8060/10000 (80.60%)
#
# Learning rate = 1.0000000000000005e-08  for epoch:  39
# EPOCH: 39
# Loss=0.6215336322784424 Batch_id=390 Accuracy=83.05: 100%|██████████| 391/391 [00:32<00:00, 11.92it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8070/10000 (80.70%)
#
# Validation accuracy increased (80.600000 --> 80.700000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  40
# EPOCH: 40
# Loss=0.4658587872982025 Batch_id=390 Accuracy=82.83: 100%|██████████| 391/391 [00:34<00:00, 11.27it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8071/10000 (80.71%)
#
# Validation accuracy increased (80.700000 --> 80.710000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  41
# EPOCH: 41
# Loss=0.33304068446159363 Batch_id=390 Accuracy=83.12: 100%|██████████| 391/391 [00:34<00:00, 11.46it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8061/10000 (80.61%)
#
# Learning rate = 1.0000000000000005e-08  for epoch:  42
# EPOCH: 42
# Loss=0.5508666038513184 Batch_id=390 Accuracy=82.92: 100%|██████████| 391/391 [00:34<00:00, 11.43it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8076/10000 (80.76%)
#
# Validation accuracy increased (80.610000 --> 80.760000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  43
# EPOCH: 43
# Loss=0.5956749320030212 Batch_id=390 Accuracy=83.11: 100%|██████████| 391/391 [00:33<00:00, 11.57it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8062/10000 (80.62%)
#
# Learning rate = 1.0000000000000005e-08  for epoch:  44
# EPOCH: 44
# Loss=0.5660699605941772 Batch_id=390 Accuracy=82.82: 100%|██████████| 391/391 [00:33<00:00, 11.64it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8062/10000 (80.62%)
#
# Validation accuracy increased (80.620000 --> 80.620000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  45
# EPOCH: 45
# Loss=0.3305688798427582 Batch_id=390 Accuracy=83.08: 100%|██████████| 391/391 [00:33<00:00, 11.54it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8082/10000 (80.82%)
#
# Validation accuracy increased (80.620000 --> 80.820000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  46
# EPOCH: 46
# Loss=0.5861412882804871 Batch_id=390 Accuracy=83.20: 100%|██████████| 391/391 [00:34<00:00, 11.47it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8050/10000 (80.50%)
#
# Learning rate = 1.0000000000000005e-08  for epoch:  47
# EPOCH: 47
# Loss=0.49529847502708435 Batch_id=390 Accuracy=83.21: 100%|██████████| 391/391 [00:34<00:00, 11.45it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8075/10000 (80.75%)
#
# Validation accuracy increased (80.500000 --> 80.750000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  48
# EPOCH: 48
# Loss=0.5288891196250916 Batch_id=390 Accuracy=82.92: 100%|██████████| 391/391 [00:31<00:00, 12.33it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8088/10000 (80.88%)
#
# Validation accuracy increased (80.750000 --> 80.880000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  49
# EPOCH: 49
# Loss=0.49531927704811096 Batch_id=390 Accuracy=83.03: 100%|██████████| 391/391 [00:32<00:00, 12.08it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8040/10000 (80.40%)
#
# Learning rate = 1.0000000000000005e-08  for epoch:  50
# EPOCH: 50
# Loss=0.3387586176395416 Batch_id=390 Accuracy=83.09: 100%|██████████| 391/391 [00:31<00:00, 12.46it/s]
# Test set: Average loss: 0.0045, Accuracy: 8043/10000 (80.43%)
#
# Validation accuracy increased (80.400000 --> 80.430000).  Saving model ...
# Learning rate = 1.0000000000000005e-08  for epoch:  51

# %%
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Accuracy of airplane: 84% (3276/3886)
# Test Accuracy of automobile: 83% (3310/3950)
# Test Accuracy of  bird: 66% (2608/3941)
# Test Accuracy of   cat: 72% (2878/3995)
# Test Accuracy of  deer: 75% (2951/3933)
# Test Accuracy of   dog: 68% (2711/3963)
# Test Accuracy of  frog: 85% (3362/3924)
# Test Accuracy of horse: 77% (3152/4053)
# Test Accuracy of  ship: 89% (3503/3916)
# Test Accuracy of truck: 79% (3122/3939)
#
# Test Accuracy (Overall): 78% (30873/39500)

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda
images = images.cuda()

# get sample outputs
output = cnn_model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(15, 20))

loc = 0
for idx in np.arange(128):
    if preds[idx]!=labels[idx].item() and loc < 25:
        ax = fig.add_subplot(5, 5, loc+1, xticks=[], yticks=[])
        utils.Utils.imshow(images[idx].cpu())
        ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]])
                     ,color="red")
        loc += 1

# %%
train_losses, train_acc = train_model.gettraindata()
test_losses, test_acc = train_model.gettestdata()
fig, axs = plt.subplots(nrows=3, ncols=2,figsize=(15,10))
axs[0, 0].plot(train_losses)
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(train_acc)
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(test_losses)
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(test_acc)
axs[1, 1].set_title("Test Accuracy")
axs[2, 0].plot(lr_data)
axs[2, 0].set_title("Learning Rate")
# axs[2, 1].plot(reg_loss_l1)
# axs[2, 1].set_title("L1 Loss")
plt.show()

# %%
utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/finalmodelwithdata.pt",optimizer_state_dict=optimizer.state_dict
                      ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
                      test_losses=test_losses)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e2aa74edf8f0> in <module>
#       1 utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/finalmodelwithdata.pt",optimizer_state_dict=optimizer.state_dict
#       2                       ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
# ----> 3                       test_losses=test_losses)
#
# TypeError: savemodel() missing 1 required positional argument: 'self'
