# %% [markdown]
# # Import Libraries

# %%
import datetime
print("Model execution started at:" + datetime.datetime.today().ctime())
# Out:
# Model execution started at:Tue Mar 17 13:54:41 2020

# %%
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
# import src.preprocessing.pytorchtransforms as preprocessing
import src.preprocessing.albumentationstransforms as preprocessing
import src.utils.utils as utils
import src.models.train_model as train
import src.visualization.plotdata as plotdata
import src.preprocessing.customcompose as customcompose

# %config IPCompleter.greedy=True
# %reload_ext autoreload

# %%
# %autoreload 2  # Autoreload all modules

# %%
def printgpuinfo():
    gpu_info = !nvidia-smi
    gpu_info = '\n'.join(gpu_info)
    if gpu_info.find('failed') >= 0:
      print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
      print('and then re-execute this cell.')
    else:
      print(gpu_info)

# %%
def showsysteminfo():
    from psutil import virtual_memory
    ram_gb = virtual_memory().total / 1e9
    print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

    if ram_gb < 20:
      print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
      print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
      print('re-execute this cell.')
    else:
      print('You are using a high-RAM runtime!')

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
# mean,std= utils.Utils.calculatemeanandstddeviation()
# print("mean: " + str(mean))
# print("std: " + str(std))
mean=[0.5,0.5,0.5]
std=[0.5,0.5,0.5]
preproc = preprocessing.AlbumentaionsTransforms()
train_transforms = preproc.gettraintransforms(mean,std)
test_transforms = preproc.gettesttransforms(mean,std)
compose_train = customcompose.CustomCompose(train_transforms)
compose_test = customcompose.CustomCompose(test_transforms)

# %%
ds = dst.Dataset()
train_dataset = ds.gettraindataset(compose_train)
test_dataset = ds.gettestdataset(compose_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 64
dataloader = dl.Cifar10Dataloader(traindataset=train_dataset, testdataset=test_dataset,batch_size=batch_size)
train_loader = dataloader.gettraindataloader()
test_loader = dataloader.gettestdataloader()
# Out:
# CUDA Available? True
# 64

# %%
# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

#TODO show transformed images fom dataset
dataiterator = iter(train_loader)
plotdata.PlotData.showImagesfromdataset(dataiterator,classes=classes)

# %%
cnn_model, device = utils.Utils.createmodelresnet18()
train_model = train.TrainModel()
train_model.showmodelsummary(cnn_model)
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
optimizer = utils.Utils.createoptimizer(cnn_model, lr=0.1, momentum=0.9, weight_decay=0)
# scheduler = utils.Utils.createscheduler(optimizer, mode='max', factor=0.1, patience=4,
#                                         verbose=True)
# scheduler = utils.Utils.createschedulersteplr(optimizer, step_size=15, gamma=0.5)

# %%
lr_data = []
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
epochs = 25
for epoch in range(1, epochs+1):
    print("EPOCH:", epoch)
    train_model.train(cnn_model, device, train_loader, optimizer, 1)
    t_acc_epoch = train_model.test(cnn_model, device, test_loader, class_correct=class_correct,
                                   class_total=class_total, epoch=epoch)
#     scheduler.step(epoch)
    for param_groups in optimizer.param_groups:
        print("Learning rate =", param_groups['lr'], " for epoch: ", epoch + 1)  # print LR for different epochs
        lr_data.append(param_groups['lr'])
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# EPOCH: 1
# /home/abhijit/.virtualenvs/dl4cv/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=1.6916484832763672 Batch_id=781 Accuracy=38.65: 100%|██████████| 782/782 [01:00<00:00, 13.01it/s]
# Test set: Average loss: 0.0221, Accuracy: 4826/10000 (48.26%)
#
# Validation accuracy increased (0.000000 --> 48.260000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  2
# EPOCH: 2
# Loss=1.2226653099060059 Batch_id=781 Accuracy=58.04: 100%|██████████| 782/782 [01:25<00:00,  9.14it/s]
# Test set: Average loss: 0.0169, Accuracy: 5963/10000 (59.63%)
#
# Validation accuracy increased (48.260000 --> 59.630000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  3
# EPOCH: 3
# Loss=0.6814228296279907 Batch_id=781 Accuracy=69.26: 100%|██████████| 782/782 [01:39<00:00,  7.86it/s]
# Test set: Average loss: 0.0138, Accuracy: 6884/10000 (68.84%)
#
# Validation accuracy increased (59.630000 --> 68.840000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  4
# EPOCH: 4
# Loss=0.6362330317497253 Batch_id=781 Accuracy=75.92: 100%|██████████| 782/782 [01:44<00:00,  7.45it/s]
# Test set: Average loss: 0.0099, Accuracy: 7765/10000 (77.65%)
#
# Validation accuracy increased (68.840000 --> 77.650000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  5
# EPOCH: 5
# Loss=0.7922706007957458 Batch_id=781 Accuracy=81.50: 100%|██████████| 782/782 [01:44<00:00,  7.49it/s]
# Test set: Average loss: 0.0098, Accuracy: 7917/10000 (79.17%)
#
# Validation accuracy increased (77.650000 --> 79.170000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  6
# EPOCH: 6
# Loss=0.40667909383773804 Batch_id=781 Accuracy=85.33: 100%|██████████| 782/782 [01:48<00:00,  7.21it/s]
# Test set: Average loss: 0.0096, Accuracy: 7927/10000 (79.27%)
#
# Validation accuracy increased (79.170000 --> 79.270000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  7
# EPOCH: 7
# Loss=0.7435836791992188 Batch_id=781 Accuracy=88.74: 100%|██████████| 782/782 [01:48<00:00,  7.20it/s]
# Test set: Average loss: 0.0096, Accuracy: 8054/10000 (80.54%)
#
# Validation accuracy increased (79.270000 --> 80.540000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  8
# EPOCH: 8
# Loss=0.44546541571617126 Batch_id=781 Accuracy=91.36: 100%|██████████| 782/782 [01:53<00:00,  6.88it/s]
# Test set: Average loss: 0.0098, Accuracy: 8171/10000 (81.71%)
#
# Validation accuracy increased (80.540000 --> 81.710000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  9
# EPOCH: 9
# Loss=0.12473097443580627 Batch_id=781 Accuracy=93.55: 100%|██████████| 782/782 [01:51<00:00,  7.01it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0104, Accuracy: 8163/10000 (81.63%)
#
# Learning rate = 0.1  for epoch:  10
# EPOCH: 10
# Loss=0.20802029967308044 Batch_id=781 Accuracy=95.37: 100%|██████████| 782/782 [01:52<00:00,  6.97it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0114, Accuracy: 8105/10000 (81.05%)
#
# Learning rate = 0.1  for epoch:  11
# EPOCH: 11
# Loss=0.5848464965820312 Batch_id=781 Accuracy=96.39: 100%|██████████| 782/782 [01:57<00:00,  6.63it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0140, Accuracy: 7933/10000 (79.33%)
#
# Learning rate = 0.1  for epoch:  12
# EPOCH: 12
# Loss=0.01913142204284668 Batch_id=781 Accuracy=97.32: 100%|██████████| 782/782 [01:55<00:00,  6.79it/s]
# Test set: Average loss: 0.0123, Accuracy: 8171/10000 (81.71%)
#
# Validation accuracy increased (81.710000 --> 81.710000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  13
# EPOCH: 13
# Loss=0.030005455017089844 Batch_id=781 Accuracy=98.03: 100%|██████████| 782/782 [01:54<00:00,  6.82it/s]
# Test set: Average loss: 0.0133, Accuracy: 8224/10000 (82.24%)
#
# Validation accuracy increased (81.710000 --> 82.240000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  14
# EPOCH: 14
# Loss=0.0034784674644470215 Batch_id=781 Accuracy=98.45: 100%|██████████| 782/782 [01:50<00:00,  7.09it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0145, Accuracy: 8182/10000 (81.82%)
#
# Learning rate = 0.1  for epoch:  15
# EPOCH: 15
# Loss=0.1026076078414917 Batch_id=781 Accuracy=98.64: 100%|██████████| 782/782 [01:52<00:00,  6.94it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0138, Accuracy: 8206/10000 (82.06%)
#
# Learning rate = 0.1  for epoch:  16
# EPOCH: 16
# Loss=0.008303701877593994 Batch_id=781 Accuracy=98.78: 100%|██████████| 782/782 [01:50<00:00,  7.07it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0146, Accuracy: 8157/10000 (81.57%)
#
# Learning rate = 0.1  for epoch:  17
# EPOCH: 17
# Loss=9.399652481079102e-05 Batch_id=781 Accuracy=99.10: 100%|██████████| 782/782 [01:50<00:00,  7.08it/s]
# Test set: Average loss: 0.0153, Accuracy: 8233/10000 (82.33%)
#
# Validation accuracy increased (82.240000 --> 82.330000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  18
# EPOCH: 18
# Loss=0.004062056541442871 Batch_id=781 Accuracy=99.27: 100%|██████████| 782/782 [01:56<00:00,  6.73it/s]
# Test set: Average loss: 0.0148, Accuracy: 8253/10000 (82.53%)
#
# Validation accuracy increased (82.330000 --> 82.530000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  19
# EPOCH: 19
# Loss=0.0007217526435852051 Batch_id=781 Accuracy=99.32: 100%|██████████| 782/782 [01:54<00:00,  6.85it/s]
# Test set: Average loss: 0.0150, Accuracy: 8260/10000 (82.60%)
#
# Validation accuracy increased (82.530000 --> 82.600000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  20
# EPOCH: 20
# Loss=0.00432276725769043 Batch_id=781 Accuracy=99.38: 100%|██████████| 782/782 [01:55<00:00,  6.77it/s]
# Test set: Average loss: 0.0154, Accuracy: 8294/10000 (82.94%)
#
# Validation accuracy increased (82.600000 --> 82.940000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  21
# EPOCH: 21
# Loss=7.30752944946289e-05 Batch_id=781 Accuracy=99.49: 100%|██████████| 782/782 [01:57<00:00,  6.65it/s]
# Test set: Average loss: 0.0152, Accuracy: 8331/10000 (83.31%)
#
# Validation accuracy increased (82.940000 --> 83.310000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.1  for epoch:  22
# EPOCH: 22
# Loss=0.0248451828956604 Batch_id=781 Accuracy=99.48: 100%|██████████| 782/782 [01:54<00:00,  6.81it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0166, Accuracy: 8237/10000 (82.37%)
#
# Learning rate = 0.1  for epoch:  23
# EPOCH: 23
# Loss=0.00047469139099121094 Batch_id=781 Accuracy=99.50: 100%|██████████| 782/782 [01:55<00:00,  6.79it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0158, Accuracy: 8250/10000 (82.50%)
#
# Learning rate = 0.1  for epoch:  24
# EPOCH: 24
# Loss=0.012415289878845215 Batch_id=781 Accuracy=99.62: 100%|██████████| 782/782 [01:57<00:00,  6.63it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0172, Accuracy: 8237/10000 (82.37%)
#
# Learning rate = 0.1  for epoch:  25
# EPOCH: 25
# Loss=0.0002799034118652344 Batch_id=781 Accuracy=99.53: 100%|██████████| 782/782 [01:57<00:00,  6.66it/s]
# Test set: Average loss: 0.0149, Accuracy: 8341/10000 (83.41%)
#
# Validation accuracy increased (83.310000 --> 83.410000).  Saving model ...
# Learning rate = 0.1  for epoch:  26

# %%
import numpy as np
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Accuracy of airplane: 81% (3147/3852)
# Test Accuracy of automobile: 88% (3504/3981)
# Test Accuracy of  bird: 68% (2734/3967)
# Test Accuracy of   cat: 67% (2658/3933)
# Test Accuracy of  deer: 75% (2979/3968)
# Test Accuracy of   dog: 66% (2604/3898)
# Test Accuracy of  frog: 81% (3117/3823)
# Test Accuracy of horse: 81% (3288/4011)
# Test Accuracy of  ship: 86% (3367/3886)
# Test Accuracy of truck: 90% (3545/3931)
#
# Test Accuracy (Overall): 78% (30943/39250)

# %%
# obtain one batch of test images
dataiterator = iter(test_loader)
plotdata.PlotData.plotmisclassifiedimages(dataiterator=dataiterator,model=cnn_model,classes=classes)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1a461f0c2661> in <module>
#       1 # obtain one batch of test images
#       2 dataiterator = iter(test_loader)
# ----> 3 plotdata.PlotData.plotmisclassifiedimages(dataiterator=dataiterator,model=cnn_model,classes=classes)
#
# ~/EVARepo/EVA/A9/src/visualization/plotdata.py in plotmisclassifiedimages(dataiterator, model, classes)
#      39         loc = 0
#      40         for idx in np.arange(128):
# ---> 41             if preds[idx] != labels[idx].item() and loc < 25:
#      42                 ax = fig.add_subplot(5, 5, loc + 1, xticks=[], yticks=[])
#      43                 from src.utils import utils
#
# IndexError: index 64 is out of bounds for axis 0 with size 64

# %%
train_losses, train_acc = train_model.gettraindata()
test_losses, test_acc = train_model.gettestdata()
plotdata.PlotData.plottesttraingraph(train_losses=train_losses,train_acc=train_acc,test_losses=test_losses,
                                     test_acc=test_acc,lr_data=lr_data)

# %%
utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/finalmodelwithdata.pt",optimizer_state_dict=optimizer.state_dict
                      ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
                      test_losses=test_losses)

# %%
import torch
import src.utils.utils as utils
print(torch.cuda.is_available())
saved_data = utils.Utils.loadmodel(path="savedmodels/finalmodelwithdata.pt")
# Out:
# True

# %%
model, device = utils.Utils.createmodelresnet18()
model.load_state_dict(state_dict=saved_data['model_state_dict'])
# Out:
# cuda
# <All keys matched successfully>

# %%
import glob
from PIL import Image
from src.utils.modelutils import ModelUtils

image_paths = glob.glob('./images/testimages/*.*')
images = list(map(lambda x: Image.open(x), image_paths))
ModelUtils.subplot(images, title='inputs', nrows=2, ncols=5)

# %%
import torchvision

inputs = [torchvision.transforms.Compose([torchvision.transforms.Resize((32, 32)), torchvision.transforms.ToTensor(),
                                          torchvision.transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])(
    x).unsqueeze(0) for x in images]  # add 1 dim for batch
inputs = [i.to(device) for i in inputs]

# %%
from src.visualization.gradcam.gradcam import gradcamof

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

gradcamof(model,inputs,classes)
# Out:
# dog
# bird
# bird
# ship
# dog
# horse
# dog
# horse
# automobile
# dog
