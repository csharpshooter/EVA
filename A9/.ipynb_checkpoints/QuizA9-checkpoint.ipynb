# %% [markdown]
# # Import Libraries

# %%
import datetime
print("Model execution started at:" + datetime.datetime.today().ctime())
# Out:
# Model execution started at:Tue Mar 17 21:59:59 2020

# %%
import src.dataset.dataset as dst
import src.dataset.dataloader as dl
import src.preprocessing.albumentationstransforms as preprocessing
import src.utils.utils as utils
import src.models.train_model as train
import src.visualization.plotdata as plotdata
import src.preprocessing.customcompose as customcompose

# %config IPCompleter.greedy=True
# %reload_ext autoreload

# %%
# %autoreload 2  # Autoreload all modules

# %%
def printgpuinfo():
    gpu_info = !nvidia-smi
    gpu_info = '\n'.join(gpu_info)
    if gpu_info.find('failed') >= 0:
      print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
      print('and then re-execute this cell.')
    else:
      print(gpu_info)

# %%
def showsysteminfo():
    from psutil import virtual_memory
    ram_gb = virtual_memory().total / 1e9
    print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

    if ram_gb < 20:
      print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
      print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
      print('re-execute this cell.')
    else:
      print('You are using a high-RAM runtime!')

# %%
import torch
print(torch.__version__)
# Out:
# 1.4.0

# %%
# mean,std= utils.Utils.calculatemeanandstddeviation()
# print("mean: " + str(mean))
# print("std: " + str(std))
mean=[0.5,0.5,0.5]
std=[0.5,0.5,0.5]
preproc = preprocessing.AlbumentaionsTransforms()
train_transforms = preproc.gettraintransforms(mean,std)
test_transforms = preproc.gettesttransforms(mean,std)
compose_train = customcompose.CustomCompose(train_transforms)
compose_test = customcompose.CustomCompose(test_transforms)

# %%
ds = dst.Dataset()
train_dataset = ds.gettraindataset(compose_train)
test_dataset = ds.gettestdataset(compose_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 64
dataloader = dl.Cifar10Dataloader(traindataset=train_dataset, testdataset=test_dataset,batch_size=batch_size)
train_loader = dataloader.gettraindataloader()
test_loader = dataloader.gettestdataloader()
# Out:
# CUDA Available? True
# 64

# %%
# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

#TODO show transformed images fom dataset
dataiterator = iter(train_loader)
plotdata.PlotData.showImagesfromdataset(dataiterator,classes=classes)

# %%
cnn_model, device = utils.Utils.createmodelquizdnn()
train_model = train.TrainModel()
train_model.showmodelsummary(cnn_model)
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#            Dropout-4           [-1, 32, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]             288
#             Conv2d-6           [-1, 32, 32, 32]           1,056
# DepthwiseSeparableConv2d-7           [-1, 32, 32, 32]               0
#        BatchNorm2d-8           [-1, 32, 32, 32]              64
#               ReLU-9           [-1, 32, 32, 32]               0
#           Dropout-10           [-1, 32, 32, 32]               0
#            Conv2d-11           [-1, 64, 30, 30]          18,432
#       BatchNorm2d-12           [-1, 64, 30, 30]             128
#              ReLU-13           [-1, 64, 30, 30]               0
#           Dropout-14           [-1, 64, 30, 30]               0
#         MaxPool2d-15           [-1, 64, 15, 15]               0
#            Conv2d-16           [-1, 32, 15, 15]          18,432
#       BatchNorm2d-17           [-1, 32, 15, 15]              64
#              ReLU-18           [-1, 32, 15, 15]               0
#           Dropout-19           [-1, 32, 15, 15]               0
#            Conv2d-20           [-1, 32, 15, 15]             288
#            Conv2d-21           [-1, 32, 15, 15]           1,056
# DepthwiseSeparableConv2d-22           [-1, 32, 15, 15]               0
#       BatchNorm2d-23           [-1, 32, 15, 15]              64
#              ReLU-24           [-1, 32, 15, 15]               0
#           Dropout-25           [-1, 32, 15, 15]               0
#            Conv2d-26           [-1, 64, 13, 13]          18,432
#       BatchNorm2d-27           [-1, 64, 13, 13]             128
#              ReLU-28           [-1, 64, 13, 13]               0
#           Dropout-29           [-1, 64, 13, 13]               0
#         MaxPool2d-30             [-1, 64, 6, 6]               0
#            Conv2d-31             [-1, 32, 6, 6]          18,432
#       BatchNorm2d-32             [-1, 32, 6, 6]              64
#              ReLU-33             [-1, 32, 6, 6]               0
#           Dropout-34             [-1, 32, 6, 6]               0
#            Conv2d-35             [-1, 32, 6, 6]             288
#            Conv2d-36             [-1, 32, 6, 6]           1,056
# DepthwiseSeparableConv2d-37             [-1, 32, 6, 6]               0
#       BatchNorm2d-38             [-1, 32, 6, 6]              64
#              ReLU-39             [-1, 32, 6, 6]               0
#           Dropout-40             [-1, 32, 6, 6]               0
#            Conv2d-41             [-1, 64, 2, 2]          18,432
#       BatchNorm2d-42             [-1, 64, 2, 2]             128
#              ReLU-43             [-1, 64, 2, 2]               0
#           Dropout-44             [-1, 64, 2, 2]               0
#         AvgPool2d-45             [-1, 64, 1, 1]               0
#            Linear-46                   [-1, 10]             640
# ================================================================
# Total params: 98,464
# Trainable params: 98,464
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.36
# Params size (MB): 0.38
# Estimated Total Size (MB): 5.75
# ----------------------------------------------------------------

# %%
optimizer = utils.Utils.createoptimizer(cnn_model, lr=0.01, momentum=0.9, weight_decay=0)
# scheduler = utils.Utils.createscheduler(optimizer, mode='max', factor=0.1, patience=4,
#                                         verbose=True)
# scheduler = utils.Utils.createschedulersteplr(optimizer, step_size=25, gamma=0.5)

# %%
lr_data = []
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
epochs = 40
for epoch in range(1, epochs+1):
    print("EPOCH:", epoch)
    train_model.train(cnn_model, device, train_loader, optimizer, 1)
    t_acc_epoch = train_model.test(cnn_model, device, test_loader, class_correct=class_correct,
                                   class_total=class_total, epoch=epoch)
#     scheduler.step(epoch)
    for param_groups in optimizer.param_groups:
        print("Learning rate =", param_groups['lr'], " for epoch: ", epoch + 1)  # print LR for different epochs
        lr_data.append(param_groups['lr'])
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# EPOCH: 1
# /home/abhijit/.virtualenvs/dl4cv/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=0.8996973037719727 Batch_id=781 Accuracy=49.80: 100%|██████████| 782/782 [00:41<00:00, 18.96it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0216, Accuracy: 5119/10000 (51.19%)
#
# Validation accuracy increased (0.000000 --> 51.190000).  Saving model ...
# Learning rate = 0.01  for epoch:  2
# EPOCH: 2
# Loss=1.3797874450683594 Batch_id=781 Accuracy=64.14: 100%|██████████| 782/782 [00:52<00:00, 14.85it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0161, Accuracy: 6348/10000 (63.48%)
#
# Validation accuracy increased (51.190000 --> 63.480000).  Saving model ...
# Learning rate = 0.01  for epoch:  3
# EPOCH: 3
# Loss=0.6686151623725891 Batch_id=781 Accuracy=69.52: 100%|██████████| 782/782 [00:46<00:00, 16.64it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0176, Accuracy: 6206/10000 (62.06%)
#
# Learning rate = 0.01  for epoch:  4
# EPOCH: 4
# Loss=1.4655107259750366 Batch_id=781 Accuracy=72.63: 100%|██████████| 782/782 [00:53<00:00, 14.58it/s]
# Test set: Average loss: 0.0117, Accuracy: 7388/10000 (73.88%)
#
# Validation accuracy increased (63.480000 --> 73.880000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.01  for epoch:  5
# EPOCH: 5
# Loss=1.1381617784500122 Batch_id=781 Accuracy=74.97: 100%|██████████| 782/782 [00:50<00:00, 15.58it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0117, Accuracy: 7388/10000 (73.88%)
#
# Validation accuracy increased (73.880000 --> 73.880000).  Saving model ...
# Learning rate = 0.01  for epoch:  6
# EPOCH: 6
# Loss=0.7696031332015991 Batch_id=781 Accuracy=76.29: 100%|██████████| 782/782 [00:51<00:00, 15.19it/s]
# Test set: Average loss: 0.0117, Accuracy: 7435/10000 (74.35%)
#
# Validation accuracy increased (73.880000 --> 74.350000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.01  for epoch:  7
# EPOCH: 7
# Loss=0.551341712474823 Batch_id=781 Accuracy=77.63: 100%|██████████| 782/782 [00:53<00:00, 14.51it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0111, Accuracy: 7555/10000 (75.55%)
#
# Validation accuracy increased (74.350000 --> 75.550000).  Saving model ...
# Learning rate = 0.01  for epoch:  8
# EPOCH: 8
# Loss=0.6642379760742188 Batch_id=781 Accuracy=78.95: 100%|██████████| 782/782 [00:53<00:00, 14.48it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0114, Accuracy: 7498/10000 (74.98%)
#
# Learning rate = 0.01  for epoch:  9
# EPOCH: 9
# Loss=0.6321515440940857 Batch_id=781 Accuracy=79.55: 100%|██████████| 782/782 [00:53<00:00, 14.53it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0106, Accuracy: 7659/10000 (76.59%)
#
# Validation accuracy increased (75.550000 --> 76.590000).  Saving model ...
# Learning rate = 0.01  for epoch:  10
# EPOCH: 10
# Loss=0.3716329038143158 Batch_id=781 Accuracy=80.40: 100%|██████████| 782/782 [00:53<00:00, 14.56it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0107, Accuracy: 7690/10000 (76.90%)
#
# Validation accuracy increased (76.590000 --> 76.900000).  Saving model ...
# Learning rate = 0.01  for epoch:  11
# EPOCH: 11
# Loss=0.43573182821273804 Batch_id=781 Accuracy=81.03: 100%|██████████| 782/782 [00:47<00:00, 16.35it/s]
# Test set: Average loss: 0.0103, Accuracy: 7783/10000 (77.83%)
#
# Validation accuracy increased (76.900000 --> 77.830000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.01  for epoch:  12
# EPOCH: 12
# Loss=1.340703010559082 Batch_id=781 Accuracy=81.75: 100%|██████████| 782/782 [00:51<00:00, 15.19it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0098, Accuracy: 7886/10000 (78.86%)
#
# Validation accuracy increased (77.830000 --> 78.860000).  Saving model ...
# Learning rate = 0.01  for epoch:  13
# EPOCH: 13
# Loss=0.3003113567829132 Batch_id=781 Accuracy=82.34: 100%|██████████| 782/782 [00:55<00:00, 14.16it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0094, Accuracy: 7969/10000 (79.69%)
#
# Validation accuracy increased (78.860000 --> 79.690000).  Saving model ...
# Learning rate = 0.01  for epoch:  14
# EPOCH: 14
# Loss=0.6319395303726196 Batch_id=781 Accuracy=82.80: 100%|██████████| 782/782 [00:52<00:00, 14.93it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0094, Accuracy: 7951/10000 (79.51%)
#
# Learning rate = 0.01  for epoch:  15
# EPOCH: 15
# Loss=0.28209418058395386 Batch_id=781 Accuracy=83.16: 100%|██████████| 782/782 [00:52<00:00, 14.86it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0088, Accuracy: 8079/10000 (80.79%)
#
# Validation accuracy increased (79.690000 --> 80.790000).  Saving model ...
# Learning rate = 0.01  for epoch:  16
# EPOCH: 16
# Loss=0.31709083914756775 Batch_id=781 Accuracy=83.48: 100%|██████████| 782/782 [00:51<00:00, 15.17it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0105, Accuracy: 7741/10000 (77.41%)
#
# Learning rate = 0.01  for epoch:  17
# EPOCH: 17
# Loss=0.30825960636138916 Batch_id=781 Accuracy=83.94: 100%|██████████| 782/782 [00:51<00:00, 15.19it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0102, Accuracy: 7824/10000 (78.24%)
#
# Learning rate = 0.01  for epoch:  18
# EPOCH: 18
# Loss=0.4987366795539856 Batch_id=781 Accuracy=84.36: 100%|██████████| 782/782 [00:51<00:00, 15.10it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0107, Accuracy: 7669/10000 (76.69%)
#
# Learning rate = 0.01  for epoch:  19
# EPOCH: 19
# Loss=0.35894399881362915 Batch_id=781 Accuracy=84.53: 100%|██████████| 782/782 [00:51<00:00, 15.11it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0100, Accuracy: 7846/10000 (78.46%)
#
# Learning rate = 0.01  for epoch:  20
# EPOCH: 20
# Loss=0.6080269813537598 Batch_id=781 Accuracy=84.95: 100%|██████████| 782/782 [00:51<00:00, 15.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0091, Accuracy: 8031/10000 (80.31%)
#
# Learning rate = 0.01  for epoch:  21
# EPOCH: 21
# Loss=0.7615559697151184 Batch_id=781 Accuracy=85.39: 100%|██████████| 782/782 [00:51<00:00, 15.22it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0094, Accuracy: 8010/10000 (80.10%)
#
# Learning rate = 0.01  for epoch:  22
# EPOCH: 22
# Loss=0.678001880645752 Batch_id=781 Accuracy=85.79: 100%|██████████| 782/782 [00:51<00:00, 15.07it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0097, Accuracy: 7927/10000 (79.27%)
#
# Learning rate = 0.01  for epoch:  23
# EPOCH: 23
# Loss=0.704620897769928 Batch_id=781 Accuracy=85.89: 100%|██████████| 782/782 [00:51<00:00, 15.08it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0089, Accuracy: 8101/10000 (81.01%)
#
# Validation accuracy increased (80.790000 --> 81.010000).  Saving model ...
# Learning rate = 0.01  for epoch:  24
# EPOCH: 24
# Loss=0.6698317527770996 Batch_id=781 Accuracy=86.16: 100%|██████████| 782/782 [00:52<00:00, 14.99it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0094, Accuracy: 8076/10000 (80.76%)
#
# Learning rate = 0.01  for epoch:  25
# EPOCH: 25
# Loss=0.4914470911026001 Batch_id=781 Accuracy=86.20: 100%|██████████| 782/782 [00:56<00:00, 13.81it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0088, Accuracy: 8152/10000 (81.52%)
#
# Validation accuracy increased (81.010000 --> 81.520000).  Saving model ...
# Learning rate = 0.01  for epoch:  26
# EPOCH: 26
# Loss=0.3603883683681488 Batch_id=781 Accuracy=86.61: 100%|██████████| 782/782 [00:50<00:00, 15.50it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0095, Accuracy: 8037/10000 (80.37%)
#
# Learning rate = 0.01  for epoch:  27
# EPOCH: 27
# Loss=0.42753148078918457 Batch_id=781 Accuracy=86.98: 100%|██████████| 782/782 [00:54<00:00, 14.47it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0096, Accuracy: 8031/10000 (80.31%)
#
# Learning rate = 0.01  for epoch:  28
# EPOCH: 28
# Loss=0.4958072900772095 Batch_id=781 Accuracy=86.69: 100%|██████████| 782/782 [00:52<00:00, 14.88it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0095, Accuracy: 8000/10000 (80.00%)
#
# Learning rate = 0.01  for epoch:  29
# EPOCH: 29
# Loss=1.0381511449813843 Batch_id=781 Accuracy=87.07: 100%|██████████| 782/782 [00:53<00:00, 14.69it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0090, Accuracy: 8138/10000 (81.38%)
#
# Learning rate = 0.01  for epoch:  30
# EPOCH: 30
# Loss=0.7281703948974609 Batch_id=781 Accuracy=87.15: 100%|██████████| 782/782 [00:53<00:00, 14.72it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0089, Accuracy: 8185/10000 (81.85%)
#
# Validation accuracy increased (81.520000 --> 81.850000).  Saving model ...
# Learning rate = 0.01  for epoch:  31
# EPOCH: 31
# Loss=0.11458278447389603 Batch_id=781 Accuracy=87.45: 100%|██████████| 782/782 [00:49<00:00, 15.80it/s]
# Test set: Average loss: 0.0085, Accuracy: 8219/10000 (82.19%)
#
# Validation accuracy increased (81.850000 --> 82.190000).  Saving model ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Learning rate = 0.01  for epoch:  32
# EPOCH: 32
# Loss=0.2715799808502197 Batch_id=781 Accuracy=87.63: 100%|██████████| 782/782 [00:51<00:00, 15.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0087, Accuracy: 8189/10000 (81.89%)
#
# Learning rate = 0.01  for epoch:  33
# EPOCH: 33
# Loss=0.11006452143192291 Batch_id=781 Accuracy=87.91: 100%|██████████| 782/782 [00:53<00:00, 14.73it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0087, Accuracy: 8159/10000 (81.59%)
#
# Learning rate = 0.01  for epoch:  34
# EPOCH: 34
# Loss=0.21404697000980377 Batch_id=781 Accuracy=88.16: 100%|██████████| 782/782 [00:52<00:00, 14.76it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0082, Accuracy: 8313/10000 (83.13%)
#
# Validation accuracy increased (82.190000 --> 83.130000).  Saving model ...
# Learning rate = 0.01  for epoch:  35
# EPOCH: 35
# Loss=0.2569936513900757 Batch_id=781 Accuracy=88.15: 100%|██████████| 782/782 [00:52<00:00, 14.85it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0086, Accuracy: 8194/10000 (81.94%)
#
# Learning rate = 0.01  for epoch:  36
# EPOCH: 36
# Loss=0.3667650818824768 Batch_id=781 Accuracy=88.37: 100%|██████████| 782/782 [00:52<00:00, 14.80it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0090, Accuracy: 8177/10000 (81.77%)
#
# Learning rate = 0.01  for epoch:  37
# EPOCH: 37
# Loss=0.1286104917526245 Batch_id=781 Accuracy=88.25: 100%|██████████| 782/782 [00:52<00:00, 14.86it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0085, Accuracy: 8248/10000 (82.48%)
#
# Learning rate = 0.01  for epoch:  38
# EPOCH: 38
# Loss=0.3531097173690796 Batch_id=781 Accuracy=88.62: 100%|██████████| 782/782 [00:53<00:00, 14.74it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0091, Accuracy: 8178/10000 (81.78%)
#
# Learning rate = 0.01  for epoch:  39
# EPOCH: 39
# Loss=0.7336956262588501 Batch_id=781 Accuracy=88.62: 100%|██████████| 782/782 [00:52<00:00, 14.80it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.0087, Accuracy: 8235/10000 (82.35%)
#
# Learning rate = 0.01  for epoch:  40
# EPOCH: 40
# Loss=0.46652230620384216 Batch_id=781 Accuracy=88.61: 100%|██████████| 782/782 [00:52<00:00, 14.80it/s]
# Test set: Average loss: 0.0091, Accuracy: 8150/10000 (81.50%)
#
# Learning rate = 0.01  for epoch:  41

# %%
import numpy as np
for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Accuracy of airplane: 76% (4844/6322)
# Test Accuracy of automobile: 82% (5186/6294)
# Test Accuracy of  bird: 75% (4732/6287)
# Test Accuracy of   cat: 65% (4130/6305)
# Test Accuracy of  deer: 83% (5090/6125)
# Test Accuracy of   dog: 65% (4178/6369)
# Test Accuracy of  frog: 87% (5574/6374)
# Test Accuracy of horse: 74% (4591/6180)
# Test Accuracy of  ship: 90% (5671/6294)
# Test Accuracy of truck: 82% (5143/6250)
#
# Test Accuracy (Overall): 78% (49139/62800)

# %%
# obtain one batch of test images
dataiterator = iter(test_loader)
plotdata.PlotData.plotmisclassifiedimages(dataiterator=dataiterator,model=cnn_model,classes=classes)

# %%
train_losses, train_acc = train_model.gettraindata()
test_losses, test_acc = train_model.gettestdata()
plotdata.PlotData.plottesttraingraph(train_losses=train_losses,train_acc=train_acc,test_losses=test_losses,
                                     test_acc=test_acc,lr_data=lr_data)

# %%
utils.Utils.savemodel(model=cnn_model,epoch=epochs,path="savedmodels/finalmodelwithdata-quizdnnA9.pt",optimizer_state_dict=optimizer.state_dict
                      ,train_losses=train_losses, train_acc=train_acc, test_acc=test_acc,
                      test_losses=test_losses)

# %%
import torch
import src.utils.utils as utils
print(torch.cuda.is_available())
saved_data = utils.Utils.loadmodel(path="savedmodels/finalmodelwithdata-quizdnnA9.pt")
# Out:
# True

# %%
model, device = utils.Utils.createmodelquizdnn()
model.load_state_dict(state_dict=saved_data['model_state_dict'])
# Out:
# cuda
# <All keys matched successfully>
